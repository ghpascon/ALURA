# %% [markdown]
# PROCEDURES SÃO AS FUNÇÕES DO MYSQL

# %% [markdown]
# LIBS

# %%
import mysql.connector
from mysql.connector import Error
import json

# %% [markdown]
# DB DATA

# %%
with open("config/db.json") as db_file:
    db_config = json.load(db_file)

# %% [markdown]
# CONNECTION

# %%
def get_db_connection():
    return mysql.connector.connect(
            host=db_config['host'],
            user=db_config['user'],
            password=db_config['password'],
            database=db_config['database']
        )

# %%
def execute_query(query, params=None):
    conn = None
    try:
        # Create connection to the database
        conn = get_db_connection()

        with conn.cursor() as cursor:
            # Log the query being executed (useful for debugging)
            print(f"\n\nExecuting query: {query} with params: {params}\n\n")

            # Use parameterized query if params are provided
            if params:
                cursor.execute(query, params)
            else:
                cursor.execute(query)

            # For SELECT queries, fetch the results
            if cursor.description:  # This indicates a SELECT query
                result = cursor.fetchall()
                print(f"Query returned {len(result)} rows.")
                return result

            # For data-modifying queries, commit the transaction
            if query.strip().lower().startswith(('insert', 'update', 'delete')):
                conn.commit()
                print(f"{cursor.rowcount} rows affected.")
                return cursor.rowcount  # Return number of affected rows

            return None

    except Error as err:
        # Log the error with details
        print(f"Error executing query: {err}")
        if conn:
            conn.rollback()  # Rollback any changes made before the error occurred
        raise  # Re-raise error for further handling if necessary

    finally:
        # Ensure the connection is closed properly
        if conn:
            if conn.is_connected():
                conn.close()

# %% [markdown]
# PRECEDURE

# %%
query = f"""
DROP PROCEDURE IF EXISTS get_clientes;

CREATE PROCEDURE get_clientes()
BEGIN
    SELECT * FROM clientes;
END
"""

result = execute_query(query)
# Out:
# Executing query:
# DROP PROCEDURE IF EXISTS get_clientes;
#
# CREATE PROCEDURE get_clientes()
# BEGIN
#     SELECT * FROM clientes;
# END
#  with params: None

# %%
query = f"""
CALL get_clientes()
"""

result = execute_query(query)
result
# Out:
# Executing query:
# CALL get_clientes()
#  with params: None
#
#
# Query returned 10000 rows.
# [('1', 'João Miguel Sales', '658.190.237-30', 'joão_352@dominio.com'),
#  ('10', 'Cauã da Mata', '162.854.379-55', 'cauã_723@dominio.com'),
#  ('100', 'Júlia Pires', '190.682.435-51', 'júlia_388@dominio.com'),
#  ('1000', 'Srta. Clara Jesus', '457.816.309-10', 'srta._827@dominio.com'),
#  ('10000', 'Ana Vitória Caldeira', '752.831.460-90', 'ana_322@dominio.com'),
#  ('1001', 'Luana Moura', '258.374.106-35', 'luana_915@dominio.com'),
#  ('1002', 'Enrico Correia', '798.240.516-94', 'enrico_443@dominio.com'),
#  ('1003', 'Paulo Vieira', '285.097.413-79', 'paulo_562@dominio.com'),
#  ('1004', 'Marina Nunes', '049.257.361-16', 'marina_776@dominio.com'),
#  ('1005', 'Júlia da Rosa', '340.158.269-06', 'júlia_749@dominio.com'),
#  ('1006', 'Gabriela Pires', '754.892.063-65', 'gabriela_743@dominio.com'),
#  ('1007', 'Elisa Fogaça', '518.620.379-30', 'elisa_847@dominio.com'),
#  ('1008', 'Alice da Paz', '187.962.543-19', 'alice_139@dominio.com'),
#  ('1009', 'Lorena da Mota', '562.149.807-02', 'lorena_342@dominio.com'),
#  ('101', 'Rafael Peixoto', '645.792.813-73', 'rafael_412@dominio.com'),
#  ('1010', 'Samuel da Rosa', '601.542.839-24', 'samuel_557@dominio.com'),
#  ('1011', 'Sr. Bernardo da Cruz', '463.509.182-15', 'sr._972@dominio.com'),
#  ('1012', 'Maria Cecília Viana', '601.329.874-22', 'maria_933@dominio.com'),
#  ('1013', 'Guilherme Costela', '176.302.945-06', 'guilherme_123@dominio.com'),
#  ('1014', 'Sr. Fernando Silva', '621.049.837-03', 'sr._465@dominio.com'),
#  ('1015', 'Lívia Fogaça', '542.073.681-08', 'lívia_538@dominio.com'),
#  ('1016', 'Maria Sophia Melo', '527.943.016-16', 'maria_142@dominio.com'),
#  ('1017', 'Ian da Rosa', '018.674.523-08', 'ian_908@dominio.com'),
#  ('1018', 'Dr. Luiz Miguel Souza', '684.513.902-42', 'dr._103@dominio.com'),
#  ('1019', 'Maria Vitória Ribeiro', '821.096.753-30', 'maria_588@dominio.com'),
#  ('102', 'Laís Almeida', '067.431.258-90', 'laís_167@dominio.com'),
#  ('1020', 'Sr. Caio Rezende', '658.041.329-89', 'sr._495@dominio.com'),
#  ('1021', 'Helena Costa', '671.053.489-84', 'helena_917@dominio.com'),
#  ('1022', 'Luiz Gustavo Costa', '816.302.495-05', 'luiz_645@dominio.com'),
#  ('1023', 'Benjamin Correia', '310.467.985-10', 'benjamin_735@dominio.com'),
#  ('1024', 'Gabriel Carvalho', '159.678.240-49', 'gabriel_688@dominio.com'),
#  ('1025', 'Isabelly da Paz', '075.869.124-67', 'isabelly_327@dominio.com'),
#  ('1026', 'Erick Oliveira', '613.952.874-73', 'erick_107@dominio.com'),
#  ('1027', 'Cecília Lopes', '254.796.803-74', 'cecília_817@dominio.com'),
#  ('1028', 'João Felipe Pinto', '743.086.951-39', 'joão_688@dominio.com'),
#  ('1029', 'Emanuella Almeida', '097.345.612-43', 'emanuella_582@dominio.com'),
#  ('103', 'Ana Vitória Nogueira', '718.952.043-05', 'ana_711@dominio.com'),
#  ('1030', 'Dra. Heloísa Campos', '586.073.149-39', 'dra._371@dominio.com'),
#  ('1031', 'Catarina Correia', '035.179.842-05', 'catarina_215@dominio.com'),
#  ('1032', 'Lorena Jesus', '234.519.608-42', 'lorena_346@dominio.com'),
#  ('1033', 'Srta. Cecília Monteiro', '038.196.452-33', 'srta._887@dominio.com'),
#  ('1034', 'Camila Santos', '510.376.982-40', 'camila_153@dominio.com'),
#  ('1035', 'Ian Sales', '310.674.985-75', 'ian_994@dominio.com'),
#  ('1036', 'Dr. Miguel da Rocha', '941.237.865-37', 'dr._826@dominio.com'),
#  ('1037', 'Sr. Leandro Teixeira', '763.820.495-65', 'sr._585@dominio.com'),
#  ('1038', 'Fernando Cardoso', '906.472.518-76', 'fernando_896@dominio.com'),
#  ('1039', 'Sra. Bianca da Rosa', '837.409.265-38', 'sra._214@dominio.com'),
#  ('104', 'Luiz Fernando Moreira', '873.965.120-77', 'luiz_305@dominio.com'),
#  ('1040', 'Theo Lopes', '907.381.246-13', 'theo_762@dominio.com'),
#  ('1041', 'Lavínia Novaes', '741.863.950-39', 'lavínia_806@dominio.com'),
#  ('1042', 'Larissa Peixoto', '147.820.693-40', 'larissa_257@dominio.com'),
#  ('1043', 'Manuela Duarte', '603.425.897-92', 'manuela_480@dominio.com'),
#  ('1044', 'Otávio Alves', '671.305.294-07', 'otávio_534@dominio.com'),
#  ('1045', 'Ana Júlia Gomes', '270.194.685-94', 'ana_275@dominio.com'),
#  ('1046', 'João Guilherme Novaes', '527.490.861-67', 'joão_988@dominio.com'),
#  ('1047', 'Sr. Gabriel Peixoto', '945.013.276-34', 'sr._700@dominio.com'),
#  ('1048', 'Ana Clara Melo', '815.637.904-75', 'ana_941@dominio.com'),
#  ('1049', 'Esther Aragão', '953.041.726-80', 'esther_766@dominio.com'),
#  ('105', 'Henrique Caldeira', '467.015.923-25', 'henrique_659@dominio.com'),
#  ('1050', 'Clarice Rocha', '410.928.376-04', 'clarice_308@dominio.com'),
#  ('1051', 'Ana Laura da Rocha', '350.841.692-51', 'ana_400@dominio.com'),
#  ('1052', 'Dr. Heitor Rezende', '396.875.214-73', 'dr._668@dominio.com'),
#  ('1053', 'Arthur Gomes', '245.308.671-53', 'arthur_821@dominio.com'),
#  ('1054', 'Pietro Pereira', '312.958.067-03', 'pietro_440@dominio.com'),
#  ('1055', 'Dr. Arthur da Cunha', '306.942.158-05', 'dr._225@dominio.com'),
#  ('1056',
#   'Gabrielly Nascimento',
#   '053.817.694-66',
#   'gabrielly_563@dominio.com'),
#  ('1057', 'Alice Teixeira', '260.753.189-68', 'alice_714@dominio.com'),
#  ('1058', 'Srta. Isabelly Cardoso', '640.852.731-08', 'srta._264@dominio.com'),
#  ('1059', 'Isabelly da Rocha', '753.641.092-16', 'isabelly_545@dominio.com'),
#  ('106', 'Mariane Nogueira', '573.684.902-00', 'mariane_954@dominio.com'),
#  ('1060', 'Nicolas Correia', '138.204.796-78', 'nicolas_284@dominio.com'),
#  ('1061', 'Bruna Caldeira', '267.039.581-30', 'bruna_712@dominio.com'),
#  ('1062', 'Sabrina Moreira', '246.190.537-16', 'sabrina_161@dominio.com'),
#  ('1063', 'Manuela Cavalcanti', '018.365.792-68', 'manuela_525@dominio.com'),
#  ('1064', 'André Almeida', '957.814.263-37', 'andré_605@dominio.com'),
#  ('1065', 'Clara Costela', '908.741.526-58', 'clara_595@dominio.com'),
#  ('1066', 'Dr. Luiz Henrique Pires', '012.473.568-17', 'dr._975@dominio.com'),
#  ('1067', 'Alana da Rosa', '645.987.120-58', 'alana_173@dominio.com'),
#  ('1068', 'Ana das Neves', '184.052.967-94', 'ana_646@dominio.com'),
#  ('1069', 'Ana Vitória Freitas', '548.109.276-01', 'ana_602@dominio.com'),
#  ('107', 'Erick Viana', '985.364.012-06', 'erick_385@dominio.com'),
#  ('1070', 'Sra. Evelyn Pires', '693.170.852-02', 'sra._722@dominio.com'),
#  ('1071', 'Erick Fogaça', '731.829.064-96', 'erick_243@dominio.com'),
#  ('1072', 'Otávio Moura', '417.586.932-82', 'otávio_386@dominio.com'),
#  ('1073', 'Júlia Gonçalves', '627.854.130-08', 'júlia_813@dominio.com'),
#  ('1074', 'Laís Mendes', '827.136.095-77', 'laís_873@dominio.com'),
#  ('1075', 'Kevin Monteiro', '073.956.184-75', 'kevin_964@dominio.com'),
#  ('1076', 'Dr. João Miguel Pires', '526.390.418-51', 'dr._930@dominio.com'),
#  ('1077', 'João Felipe da Mata', '605.147.823-07', 'joão_800@dominio.com'),
#  ('1078', 'Dra. Eloah Azevedo', '146.905.783-20', 'dra._453@dominio.com'),
#  ('1079', 'Antônio Ferreira', '417.823.069-78', 'antônio_615@dominio.com'),
#  ('108', 'Fernanda da Costa', '073.421.586-07', 'fernanda_140@dominio.com'),
#  ('1080', 'Alice Oliveira', '139.620.548-98', 'alice_695@dominio.com'),
#  ('1081', 'Laura Costela', '157.830.924-79', 'laura_649@dominio.com'),
#  ('1082', 'Rafaela Nunes', '873.295.140-04', 'rafaela_217@dominio.com'),
#  ('1083', 'Heloísa Rodrigues', '689.710.342-03', 'heloísa_739@dominio.com'),
#  ('1084', 'Maria Julia Cardoso', '762.893.150-21', 'maria_467@dominio.com'),
#  ('1085', 'Otávio da Mata', '468.103.725-71', 'otávio_983@dominio.com'),
#  ('1086', 'Dra. Bruna Dias', '950.814.263-42', 'dra._383@dominio.com'),
#  ('1087', 'Joaquim Lima', '798.452.301-05', 'joaquim_937@dominio.com'),
#  ('1088', 'Bianca da Conceição', '792.654.830-83', 'bianca_320@dominio.com'),
#  ('1089', 'Ana Lívia Barbosa', '467.805.192-94', 'ana_301@dominio.com'),
#  ('109', 'Caio Aragão', '915.084.723-60', 'caio_118@dominio.com'),
#  ('1090', 'Gabriela Ribeiro', '681.734.290-22', 'gabriela_757@dominio.com'),
#  ('1091', 'Pedro Miguel Novaes', '290.743.861-13', 'pedro_509@dominio.com'),
#  ('1092', 'Maria Alice Souza', '021.593.476-80', 'maria_815@dominio.com'),
#  ('1093', 'Yago Nascimento', '308.419.576-57', 'yago_791@dominio.com'),
#  ('1094', 'Mirella Lopes', '540.283.697-38', 'mirella_576@dominio.com'),
#  ('1095', 'Heitor Moraes', '568.940.237-00', 'heitor_791@dominio.com'),
#  ('1096', 'Olivia Aragão', '415.906.273-34', 'olivia_485@dominio.com'),
#  ('1097',
#   'Luiz Fernando da Conceição',
#   '493.287.501-05',
#   'luiz_214@dominio.com'),
#  ('1098', 'Alícia Farias', '250.897.463-38', 'alícia_275@dominio.com'),
#  ('1099', 'Dra. Lívia Moreira', '186.507.349-01', 'dra._171@dominio.com'),
#  ('11', 'Maria Fernanda Aragão', '064.973.258-83', 'maria_181@dominio.com'),
#  ('110', 'Pedro Lucas Nascimento', '148.036.257-35', 'pedro_845@dominio.com'),
#  ('1100', 'Nicolas Rocha', '521.309.748-05', 'nicolas_350@dominio.com'),
#  ('1101', 'Emanuelly Costa', '915.207.348-32', 'emanuelly_320@dominio.com'),
#  ('1102', 'Erick Aragão', '490.831.267-22', 'erick_217@dominio.com'),
#  ('1103', 'Alícia Nunes', '194.560.783-10', 'alícia_424@dominio.com'),
#  ('1104', 'Breno Sales', '296.750.418-11', 'breno_601@dominio.com'),
#  ('1105', 'Dra. Agatha Cardoso', '178.902.543-50', 'dra._322@dominio.com'),
#  ('1106', 'Catarina Teixeira', '973.502.846-83', 'catarina_525@dominio.com'),
#  ('1107', 'Elisa Peixoto', '605.923.784-38', 'elisa_186@dominio.com'),
#  ('1108', 'Bruno Araújo', '698.415.307-75', 'bruno_452@dominio.com'),
#  ('1109', 'Benício Teixeira', '312.470.986-13', 'benício_487@dominio.com'),
#  ('111', 'Yasmin Moraes', '041.967.852-20', 'yasmin_821@dominio.com'),
#  ('1110', 'Srta. Clarice Azevedo', '420.139.568-51', 'srta._564@dominio.com'),
#  ('1111', 'Eduardo Rezende', '309.758.421-88', 'eduardo_783@dominio.com'),
#  ('1112', 'Luiz Felipe Silveira', '530.896.417-39', 'luiz_771@dominio.com'),
#  ('1113', 'Erick Teixeira', '397.046.251-70', 'erick_357@dominio.com'),
#  ('1114', 'Alana Lima', '475.608.213-08', 'alana_453@dominio.com'),
#  ('1115', 'Dra. Juliana Vieira', '853.126.407-35', 'dra._630@dominio.com'),
#  ('1116',
#   'Dra. Maria Vitória Alves',
#   '962.578.340-74',
#   'dra._661@dominio.com'),
#  ('1117', 'Alice Carvalho', '760.123.849-04', 'alice_769@dominio.com'),
#  ('1118', 'Henrique Rodrigues', '349.125.706-99', 'henrique_859@dominio.com'),
#  ('1119', 'Dra. Larissa Nogueira', '769.128.453-55', 'dra._706@dominio.com'),
#  ('112', 'Bruna Campos', '712.345.896-64', 'bruna_869@dominio.com'),
#  ('1120', 'Sra. Olivia Fogaça', '658.307.194-01', 'sra._736@dominio.com'),
#  ('1121', 'Agatha Teixeira', '430.897.516-66', 'agatha_297@dominio.com'),
#  ('1122', 'Fernanda Farias', '367.859.401-84', 'fernanda_722@dominio.com'),
#  ('1123', 'Nicole Azevedo', '901.267.543-06', 'nicole_599@dominio.com'),
#  ('1124', 'Sophia Alves', '476.932.581-91', 'sophia_628@dominio.com'),
#  ('1125', 'Sr. Eduardo Campos', '289.754.316-73', 'sr._740@dominio.com'),
#  ('1126', 'Davi Luiz Melo', '547.139.206-06', 'davi_114@dominio.com'),
#  ('1127', 'Carlos Eduardo Fogaça', '541.028.367-80', 'carlos_718@dominio.com'),
#  ('1128', 'Sr. Leonardo Fernandes', '134.027.596-16', 'sr._739@dominio.com'),
#  ('1129', 'Bruna Silveira', '489.031.256-06', 'bruna_166@dominio.com'),
#  ('113', 'Bianca Caldeira', '841.056.327-44', 'bianca_537@dominio.com'),
#  ('1130', 'Raquel Vieira', '826.510.349-24', 'raquel_152@dominio.com'),
#  ('1131', 'Raquel Peixoto', '430.976.152-61', 'raquel_947@dominio.com'),
#  ('1132', 'Alice Castro', '692.037.481-13', 'alice_755@dominio.com'),
#  ('1133', 'Davi da Luz', '053.294.786-00', 'davi_108@dominio.com'),
#  ('1134', 'Davi Luiz Silveira', '971.465.820-94', 'davi_813@dominio.com'),
#  ('1135', 'Dr. Bernardo Cardoso', '983.650.214-98', 'dr._665@dominio.com'),
#  ('1136', 'Heitor da Mota', '564.370.219-34', 'heitor_248@dominio.com'),
#  ('1137', 'Bruna Fogaça', '326.045.718-62', 'bruna_495@dominio.com'),
#  ('1138', 'Sabrina Sales', '615.708.239-95', 'sabrina_418@dominio.com'),
#  ('1139', 'Levi Aragão', '529.874.160-67', 'levi_423@dominio.com'),
#  ('114', 'Otávio Oliveira', '513.602.984-60', 'otávio_807@dominio.com'),
#  ('1140', 'Otávio da Rosa', '069.715.438-66', 'otávio_563@dominio.com'),
#  ('1141', 'Milena Mendes', '095.417.236-16', 'milena_296@dominio.com'),
#  ('1142', 'Maysa Teixeira', '830.147.659-10', 'maysa_127@dominio.com'),
#  ('1143', 'Bianca Moraes', '012.839.546-05', 'bianca_368@dominio.com'),
#  ('1144', 'Isaac Barbosa', '638.417.529-00', 'isaac_600@dominio.com'),
#  ('1145', 'Cecília Fogaça', '814.325.609-05', 'cecília_743@dominio.com'),
#  ('1146', 'Levi Peixoto', '823.659.017-86', 'levi_664@dominio.com'),
#  ('1147', 'Dra. Sophia da Paz', '230.849.567-74', 'dra._501@dominio.com'),
#  ('1148', 'Natália Gonçalves', '128.560.943-33', 'natália_226@dominio.com'),
#  ('1149', 'Lorena Nogueira', '103.985.642-05', 'lorena_360@dominio.com'),
#  ('115', 'Leandro Ribeiro', '825.739.146-82', 'leandro_666@dominio.com'),
#  ('1150', 'Alexandre Martins', '957.683.201-21', 'alexandre_519@dominio.com'),
#  ('1151', 'Pedro Lucas Peixoto', '238.751.406-80', 'pedro_622@dominio.com'),
#  ('1152', 'Stephany da Rocha', '678.951.203-95', 'stephany_618@dominio.com'),
#  ('1153', 'Kamilly Rodrigues', '167.524.893-19', 'kamilly_478@dominio.com'),
#  ('1154', 'Emanuel da Costa', '621.908.453-51', 'emanuel_229@dominio.com'),
#  ('1155', 'Dr. Igor Costela', '801.534.927-32', 'dr._573@dominio.com'),
#  ('1156', 'Calebe Castro', '697.401.328-04', 'calebe_387@dominio.com'),
#  ('1157', 'Kaique Porto', '026.198.735-68', 'kaique_595@dominio.com'),
#  ('1158', 'Giovanna Araújo', '267.410.395-70', 'giovanna_414@dominio.com'),
#  ('1159', 'Davi Lucas Carvalho', '794.186.205-02', 'davi_844@dominio.com'),
#  ('116', 'Clarice Cavalcanti', '328.410.679-04', 'clarice_318@dominio.com'),
#  ('1160', 'Maria Sophia Ferreira', '452.183.069-24', 'maria_968@dominio.com'),
#  ('1161', 'Stella Vieira', '798.160.342-04', 'stella_298@dominio.com'),
#  ('1162', 'Gustavo Rezende', '451.692.830-24', 'gustavo_727@dominio.com'),
#  ('1163', 'Sr. Nicolas Correia', '942.083.576-65', 'sr._171@dominio.com'),
#  ('1164', 'Sr. Miguel da Luz', '394.051.768-20', 'sr._746@dominio.com'),
#  ('1165', 'Maria Clara Alves', '501.687.249-01', 'maria_915@dominio.com'),
#  ('1166', 'Daniela da Mota', '562.489.307-83', 'daniela_875@dominio.com'),
#  ('1167', 'Dr. Ryan da Rosa', '790.658.432-56', 'dr._840@dominio.com'),
#  ('1168', 'Vinicius Oliveira', '061.849.253-42', 'vinicius_648@dominio.com'),
#  ('1169', 'Eduardo Dias', '789.146.502-94', 'eduardo_624@dominio.com'),
#  ('117', 'Otávio Freitas', '340.276.895-00', 'otávio_105@dominio.com'),
#  ('1170', 'Joana Ramos', '832.754.691-00', 'joana_775@dominio.com'),
#  ('1171', 'Igor Costela', '187.956.043-75', 'igor_612@dominio.com'),
#  ('1172', 'Erick Campos', '425.607.391-43', 'erick_177@dominio.com'),
#  ('1173', 'Heloísa da Rocha', '812.670.359-86', 'heloísa_493@dominio.com'),
#  ('1174', 'Marina Ribeiro', '571.203.869-21', 'marina_551@dominio.com'),
#  ('1175', 'Melissa Jesus', '861.374.059-66', 'melissa_961@dominio.com'),
#  ('1176', 'João Vitor Barbosa', '386.549.201-06', 'joão_442@dominio.com'),
#  ('1177',
#   'Gustavo Henrique Monteiro',
#   '524.780.139-32',
#   'gustavo_503@dominio.com'),
#  ('1178', 'Bruno Freitas', '479.132.650-43', 'bruno_512@dominio.com'),
#  ('1179', 'Pedro Costa', '251.906.437-43', 'pedro_896@dominio.com'),
#  ('118', 'Leandro Carvalho', '359.487.102-97', 'leandro_846@dominio.com'),
#  ('1180', 'Beatriz Barbosa', '890.357.641-10', 'beatriz_553@dominio.com'),
#  ('1181', 'Pietro Moreira', '630.452.817-53', 'pietro_293@dominio.com'),
#  ('1182', 'Heitor da Rosa', '810.695.742-01', 'heitor_909@dominio.com'),
#  ('1183', 'Isabelly Gonçalves', '402.189.537-04', 'isabelly_701@dominio.com'),
#  ('1184', 'Luna Cavalcanti', '963.078.215-40', 'luna_700@dominio.com'),
#  ('1185', 'Ana Carolina Moreira', '412.586.790-94', 'ana_619@dominio.com'),
#  ('1186', 'Srta. Cecília Jesus', '792.083.654-92', 'srta._752@dominio.com'),
#  ('1187', 'Nicolas Santos', '372.548.096-65', 'nicolas_291@dominio.com'),
#  ('1188', 'Valentina Cunha', '643.715.802-62', 'valentina_478@dominio.com'),
#  ('1189', 'Srta. Isabelly Souza', '035.692.487-47', 'srta._180@dominio.com'),
#  ('119', 'Sr. Thomas Azevedo', '027.481.369-69', 'sr._368@dominio.com'),
#  ('1190', 'Henrique Souza', '280.357.461-62', 'henrique_681@dominio.com'),
#  ('1191', 'Srta. Ana Nogueira', '435.186.079-01', 'srta._950@dominio.com'),
#  ('1192', 'Fernanda Araújo', '430.621.897-03', 'fernanda_172@dominio.com'),
#  ('1193',
#   'Srta. Maria Cecília Pires',
#   '670.382.541-62',
#   'srta._528@dominio.com'),
#  ('1194', 'Kaique Cardoso', '578.406.123-26', 'kaique_486@dominio.com'),
#  ('1195', 'Dra. Laís Sales', '531.627.840-26', 'dra._798@dominio.com'),
#  ('1196', 'Larissa da Mata', '752.394.681-09', 'larissa_229@dominio.com'),
#  ('1197', 'Emanuella Teixeira', '136.054.297-34', 'emanuella_291@dominio.com'),
#  ('1198', 'Carlos Eduardo Pinto', '386.125.749-19', 'carlos_317@dominio.com'),
#  ('1199', 'Isabelly da Mata', '642.301.895-24', 'isabelly_383@dominio.com'),
#  ('12', 'João Miguel da Rosa', '583.104.692-33', 'joão_154@dominio.com'),
#  ('120', 'Rafaela da Cruz', '810.693.245-15', 'rafaela_321@dominio.com'),
#  ('1200', 'Maria Clara Dias', '529.463.708-10', 'maria_189@dominio.com'),
#  ('1201', 'Srta. Isabel Carvalho', '837.269.451-64', 'srta._666@dominio.com'),
#  ('1202', 'Miguel Fogaça', '324.678.091-96', 'miguel_220@dominio.com'),
#  ('1203', 'Diego Costa', '158.497.602-02', 'diego_430@dominio.com'),
#  ('1204', 'Caroline Farias', '926.701.483-87', 'caroline_648@dominio.com'),
#  ('1205', 'Dr. Thales Vieira', '325.968.147-73', 'dr._844@dominio.com'),
#  ('1206', 'Nathan Almeida', '758.403.162-53', 'nathan_404@dominio.com'),
#  ('1207', 'Sra. Lara Souza', '042.619.783-69', 'sra._220@dominio.com'),
#  ('1208', 'Breno Pinto', '475.361.029-25', 'breno_235@dominio.com'),
#  ('1209', 'Lara da Costa', '976.482.501-01', 'lara_561@dominio.com'),
#  ('121', 'Renan Cardoso', '241.768.093-96', 'renan_557@dominio.com'),
#  ('1210', 'Dra. Manuela Farias', '024.753.891-41', 'dra._667@dominio.com'),
#  ('1211', 'Heitor Lima', '713.482.560-44', 'heitor_178@dominio.com'),
#  ('1212',
#   'Gustavo Henrique Santos',
#   '980.764.513-10',
#   'gustavo_875@dominio.com'),
#  ('1213', 'Eduarda Costela', '521.609.783-02', 'eduarda_574@dominio.com'),
#  ('1214', 'Vitor Gabriel Moraes', '019.342.876-87', 'vitor_584@dominio.com'),
#  ('1215', 'João Pedro Teixeira', '560.732.418-44', 'joão_837@dominio.com'),
#  ('1216', 'Esther Almeida', '752.813.649-28', 'esther_315@dominio.com'),
#  ('1217', 'Maria Fernanda Campos', '514.892.306-70', 'maria_877@dominio.com'),
#  ('1218', 'Vitor Hugo Aragão', '409.681.273-04', 'vitor_274@dominio.com'),
#  ('1219', 'Lucas Cardoso', '308.425.917-88', 'lucas_944@dominio.com'),
#  ('122', 'Manuela Monteiro', '047.869.231-50', 'manuela_233@dominio.com'),
#  ('1220', 'Igor Melo', '491.856.302-33', 'igor_897@dominio.com'),
#  ('1221', 'Eloah Moraes', '785.260.194-49', 'eloah_771@dominio.com'),
#  ('1222', 'Dr. Cauã Azevedo', '653.841.970-48', 'dr._340@dominio.com'),
#  ('1223', 'Sophie Freitas', '725.031.469-61', 'sophie_345@dominio.com'),
#  ('1224', 'Diogo Santos', '261.534.087-53', 'diogo_343@dominio.com'),
#  ('1225', 'Julia Gonçalves', '137.506.248-44', 'julia_965@dominio.com'),
#  ('1226', 'Ana Luiza das Neves', '958.231.706-02', 'ana_684@dominio.com'),
#  ('1227', 'Maria Alice Souza', '043.875.296-10', 'maria_735@dominio.com'),
#  ('1228', 'Maria Vitória Freitas', '527.098.134-32', 'maria_349@dominio.com'),
#  ('1229', 'Elisa Farias', '925.407.813-14', 'elisa_522@dominio.com'),
#  ('123', 'Kaique da Paz', '098.415.327-60', 'kaique_142@dominio.com'),
#  ('1230', 'Heitor Cunha', '875.610.923-77', 'heitor_640@dominio.com'),
#  ('1231', 'Srta. Elisa Mendes', '681.703.954-10', 'srta._402@dominio.com'),
#  ('1232', 'Caio Gomes', '016.489.357-10', 'caio_344@dominio.com'),
#  ('1233', 'Dra. Lara Nascimento', '763.802.591-12', 'dra._285@dominio.com'),
#  ('1234', 'Valentina Farias', '094.365.128-05', 'valentina_405@dominio.com'),
#  ('1235', 'Benjamin Pereira', '380.794.516-48', 'benjamin_495@dominio.com'),
#  ('1236', 'João Vitor Melo', '394.872.506-38', 'joão_771@dominio.com'),
#  ('1237', 'Larissa Cardoso', '457.023.819-04', 'larissa_845@dominio.com'),
#  ('1238', 'Esther Pereira', '749.830.652-29', 'esther_354@dominio.com'),
#  ('1239', 'Srta. Helena Azevedo', '649.510.237-25', 'srta._666@dominio.com'),
#  ('124',
#   'Giovanna da Conceição',
#   '749.501.268-49',
#   'giovanna_406@dominio.com'),
#  ('1240', 'Leandro Melo', '462.513.089-15', 'leandro_880@dominio.com'),
#  ('1241', 'Brenda da Cruz', '491.268.375-28', 'brenda_409@dominio.com'),
#  ('1242', 'André Rocha', '512.063.847-35', 'andré_121@dominio.com'),
#  ('1243', 'Vitor Hugo da Rocha', '574.821.309-50', 'vitor_719@dominio.com'),
#  ('1244', 'Bryan Nascimento', '564.328.179-19', 'bryan_122@dominio.com'),
#  ('1245', 'Júlia Cardoso', '372.815.409-14', 'júlia_108@dominio.com'),
#  ('1246', 'Cecília Freitas', '085.372.419-97', 'cecília_692@dominio.com'),
#  ('1247', 'Cauã Melo', '218.609.347-22', 'cauã_790@dominio.com'),
#  ('1248', 'Benjamin da Cunha', '419.620.758-85', 'benjamin_769@dominio.com'),
#  ('1249', 'Rodrigo Monteiro', '380.642.157-90', 'rodrigo_145@dominio.com'),
#  ('125', 'Enzo Cardoso', '627.145.980-30', 'enzo_969@dominio.com'),
#  ('1250', 'Bruno Costa', '392.564.078-92', 'bruno_412@dominio.com'),
#  ('1251', 'Sr. Nicolas da Costa', '658.207.391-59', 'sr._621@dominio.com'),
#  ('1252', 'Sr. Otávio Sales', '410.659.327-07', 'sr._600@dominio.com'),
#  ('1253', 'Lucas Cavalcanti', '859.021.746-94', 'lucas_996@dominio.com'),
#  ('1254', 'Maria Clara da Mata', '074.138.592-97', 'maria_341@dominio.com'),
#  ('1255', 'Lorena Monteiro', '458.769.023-65', 'lorena_627@dominio.com'),
#  ('1256', 'Manuela Araújo', '425.836.971-37', 'manuela_657@dominio.com'),
#  ('1257', 'Caio Fernandes', '681.430.975-01', 'caio_184@dominio.com'),
#  ('1258', 'Maria da Conceição', '579.421.860-67', 'maria_589@dominio.com'),
#  ('1259', 'Ana Beatriz da Luz', '794.051.386-93', 'ana_727@dominio.com'),
#  ('126', 'Manuela Nascimento', '896.530.427-00', 'manuela_394@dominio.com'),
#  ('1260', 'Joaquim da Rocha', '631.805.249-60', 'joaquim_271@dominio.com'),
#  ('1261', 'Benjamin Pinto', '283.490.615-70', 'benjamin_482@dominio.com'),
#  ('1262', 'Maria Clara Teixeira', '726.085.941-58', 'maria_198@dominio.com'),
#  ('1263', 'Renan das Neves', '501.493.786-10', 'renan_579@dominio.com'),
#  ('1264', 'Gabriela Alves', '649.308.715-57', 'gabriela_773@dominio.com'),
#  ('1265', 'Marcelo Oliveira', '824.613.957-64', 'marcelo_265@dominio.com'),
#  ('1266', 'Pedro Miguel das Neves', '453.102.896-15', 'pedro_961@dominio.com'),
#  ('1267', 'Vicente Moraes', '384.095.176-39', 'vicente_559@dominio.com'),
#  ('1268', 'Enzo Gabriel da Cruz', '648.731.209-69', 'enzo_636@dominio.com'),
#  ('1269', 'Nathan Castro', '745.016.938-00', 'nathan_221@dominio.com'),
#  ('127', 'Murilo Oliveira', '798.321.564-91', 'murilo_809@dominio.com'),
#  ('1270', 'Yuri das Neves', '482.561.730-17', 'yuri_797@dominio.com'),
#  ('1271', 'Davi Luiz Moura', '240.713.985-23', 'davi_533@dominio.com'),
#  ('1272', 'Júlia Rezende', '596.187.423-00', 'júlia_689@dominio.com'),
#  ('1273', 'Dr. Gustavo Rodrigues', '621.945.083-33', 'dr._193@dominio.com'),
#  ('1274', 'Milena Cardoso', '235.687.490-92', 'milena_940@dominio.com'),
#  ('1275', 'Maysa Rocha', '701.643.258-08', 'maysa_556@dominio.com'),
#  ('1276', 'João Porto', '170.649.385-10', 'joão_460@dominio.com'),
#  ('1277', 'Ana Correia', '092.541.837-41', 'ana_323@dominio.com'),
#  ('1278', 'Bruno Teixeira', '485.693.170-93', 'bruno_733@dominio.com'),
#  ('1279', 'Fernanda Lopes', '237.184.650-35', 'fernanda_184@dominio.com'),
#  ('128', 'Srta. Evelyn Rodrigues', '426.589.013-05', 'srta._990@dominio.com'),
#  ('1280', 'Melissa da Cunha', '859.401.673-57', 'melissa_700@dominio.com'),
#  ('1281', 'Júlia Campos', '341.529.860-42', 'júlia_636@dominio.com'),
#  ('1282', 'Sra. Milena Moraes', '941.382.705-23', 'sra._962@dominio.com'),
#  ('1283', 'Alana Dias', '397.804.526-56', 'alana_290@dominio.com'),
#  ('1284', 'Ana Luiza da Cruz', '094.628.513-60', 'ana_128@dominio.com'),
#  ('1285', 'Sr. João Miguel Correia', '570.963.142-61', 'sr._611@dominio.com'),
#  ('1286', 'Fernanda Jesus', '053.648.921-15', 'fernanda_135@dominio.com'),
#  ('1287', 'Henrique das Neves', '306.275.148-71', 'henrique_473@dominio.com'),
#  ('1288', 'Lívia da Cruz', '641.839.205-15', 'lívia_343@dominio.com'),
#  ('1289', 'Maysa Aragão', '578.601.432-08', 'maysa_781@dominio.com'),
#  ('129', 'Noah Alves', '954.302.671-80', 'noah_537@dominio.com'),
#  ('1290', 'Cauã da Cunha', '609.584.172-02', 'cauã_971@dominio.com'),
#  ('1291', 'Nicolas Caldeira', '308.579.461-10', 'nicolas_156@dominio.com'),
#  ('1292', 'Vitor Hugo Peixoto', '981.760.435-75', 'vitor_602@dominio.com'),
#  ('1293', 'Sra. Natália da Cruz', '821.469.530-98', 'sra._968@dominio.com'),
#  ('1294', 'Maria Julia Martins', '213.594.087-97', 'maria_259@dominio.com'),
#  ('1295', 'Camila Alves', '963.018.257-21', 'camila_372@dominio.com'),
#  ('1296', 'Sophia Fernandes', '650.824.137-08', 'sophia_645@dominio.com'),
#  ('1297', 'Alice Peixoto', '951.764.328-46', 'alice_718@dominio.com'),
#  ('1298', 'Bryan Pires', '719.084.653-01', 'bryan_984@dominio.com'),
#  ('1299', 'Sra. Ana Luiza Oliveira', '203.617.945-25', 'sra._771@dominio.com'),
#  ('13', 'Joaquim Barbosa', '295.701.486-67', 'joaquim_409@dominio.com'),
#  ('130', 'Fernanda Azevedo', '923.456.807-92', 'fernanda_373@dominio.com'),
#  ('1300', 'Otávio Monteiro', '240.158.973-23', 'otávio_659@dominio.com'),
#  ('1301', 'Vicente Almeida', '478.620.953-83', 'vicente_796@dominio.com'),
#  ('1302', 'Helena Lima', '982.307.465-83', 'helena_979@dominio.com'),
#  ('1303', 'Valentina Ferreira', '695.780.423-29', 'valentina_286@dominio.com'),
#  ('1304', 'Luigi Barbosa', '756.218.039-30', 'luigi_988@dominio.com'),
#  ('1305', 'Maria Sophia Vieira', '017.645.382-26', 'maria_462@dominio.com'),
#  ('1306', 'Noah Cardoso', '601.952.873-12', 'noah_902@dominio.com'),
#  ('1307', 'Vicente Martins', '851.206.947-30', 'vicente_758@dominio.com'),
#  ('1308', 'Sra. Gabrielly Cardoso', '516.043.289-24', 'sra._547@dominio.com'),
#  ('1309', 'Alice Santos', '364.291.870-04', 'alice_281@dominio.com'),
#  ('131', 'Bianca Carvalho', '039.862.514-05', 'bianca_626@dominio.com'),
#  ('1310', 'Ana Julia da Cunha', '690.243.581-24', 'ana_240@dominio.com'),
#  ('1311', 'Sr. Davi Lucca Carvalho', '874.536.019-75', 'sr._723@dominio.com'),
#  ('1312', 'Sr. Vitor Gonçalves', '053.784.296-92', 'sr._667@dominio.com'),
#  ('1313', 'Lucas Cunha', '804.593.162-06', 'lucas_661@dominio.com'),
#  ('1314', 'Srta. Marcela Pereira', '519.608.247-67', 'srta._306@dominio.com'),
#  ('1315', 'Lara da Mota', '791.053.826-02', 'lara_569@dominio.com'),
#  ('1316', 'Heloísa Nunes', '074.531.289-60', 'heloísa_904@dominio.com'),
#  ('1317', 'Julia Carvalho', '684.530.721-08', 'julia_844@dominio.com'),
#  ('1318', 'Fernanda Ribeiro', '634.801.259-05', 'fernanda_990@dominio.com'),
#  ('1319', 'Isis Rodrigues', '053.917.246-43', 'isis_249@dominio.com'),
#  ('132', 'Davi Lucca Martins', '947.362.805-65', 'davi_509@dominio.com'),
#  ('1320', 'Dra. Ana Sophia Porto', '430.857.296-74', 'dra._255@dominio.com'),
#  ('1321', 'Sr. Thiago Aragão', '136.472.508-80', 'sr._164@dominio.com'),
#  ('1322', 'Mirella Cavalcanti', '849.610.573-39', 'mirella_662@dominio.com'),
#  ('1323', 'Sophia Gonçalves', '507.134.296-07', 'sophia_949@dominio.com'),
#  ('1324', 'Daniel Cardoso', '506.892.714-76', 'daniel_504@dominio.com'),
#  ('1325', 'Paulo Pereira', '736.859.214-28', 'paulo_292@dominio.com'),
#  ('1326', 'Cauê Aragão', '360.814.592-33', 'cauê_913@dominio.com'),
#  ('1327',
#   'Srta. Nicole da Conceição',
#   '873.912.504-14',
#   'srta._842@dominio.com'),
#  ('1328', 'Dr. Levi da Cunha', '036.915.872-59', 'dr._600@dominio.com'),
#  ('1329', 'Henrique Almeida', '867.930.145-01', 'henrique_320@dominio.com'),
#  ('133', 'Felipe Melo', '638.279.054-00', 'felipe_728@dominio.com'),
#  ('1330', 'Paulo Pires', '106.438.257-62', 'paulo_631@dominio.com'),
#  ('1331', 'Luana da Mota', '258.641.730-53', 'luana_890@dominio.com'),
#  ('1332', 'Sr. Enzo Gabriel Castro', '247.016.893-78', 'sr._351@dominio.com'),
#  ('1333', 'Letícia Ramos', '312.469.785-55', 'letícia_910@dominio.com'),
#  ('1334',
#   'Marcos Vinicius Almeida',
#   '549.836.017-75',
#   'marcos_387@dominio.com'),
#  ('1335', 'Arthur da Mota', '621.073.894-03', 'arthur_743@dominio.com'),
#  ('1336', 'Isis Rodrigues', '745.906.182-49', 'isis_973@dominio.com'),
#  ('1337', 'Carlos Eduardo Farias', '476.125.830-62', 'carlos_652@dominio.com'),
#  ('1338', 'Ana Luiza Almeida', '945.781.620-01', 'ana_118@dominio.com'),
#  ('1339', 'Sr. Rafael Gonçalves', '475.216.390-06', 'sr._693@dominio.com'),
#  ('134', 'Alícia Vieira', '256.704.819-76', 'alícia_139@dominio.com'),
#  ('1340', 'Ana Julia Moreira', '103.946.752-07', 'ana_876@dominio.com'),
#  ('1341', 'Maysa Melo', '864.527.019-67', 'maysa_459@dominio.com'),
#  ('1342', 'Sr. Daniel Oliveira', '610.894.735-75', 'sr._449@dominio.com'),
#  ('1343', 'Helena Martins', '593.670.841-10', 'helena_651@dominio.com'),
#  ('1344', 'Isabelly da Paz', '164.583.920-60', 'isabelly_671@dominio.com'),
#  ('1345', 'Marcela Caldeira', '659.273.041-25', 'marcela_141@dominio.com'),
#  ('1346', 'Ana Clara Castro', '247.106.385-35', 'ana_662@dominio.com'),
#  ('1347', 'Nicolas Ribeiro', '201.473.589-14', 'nicolas_512@dominio.com'),
#  ('1348', 'Bernardo Moura', '087.961.542-76', 'bernardo_785@dominio.com'),
#  ('1349', 'Larissa Lima', '837.612.904-03', 'larissa_717@dominio.com'),
#  ('135', 'Rodrigo Freitas', '892.017.546-20', 'rodrigo_650@dominio.com'),
#  ('1350', 'Rebeca Araújo', '170.624.983-78', 'rebeca_151@dominio.com'),
#  ('1351', 'Larissa Teixeira', '415.826.390-51', 'larissa_864@dominio.com'),
#  ('1352', 'João Pedro Barbosa', '867.032.145-90', 'joão_427@dominio.com'),
#  ('1353', 'Joaquim da Cruz', '768.215.034-35', 'joaquim_212@dominio.com'),
#  ('1354', 'Bryan Dias', '063.158.749-75', 'bryan_694@dominio.com'),
#  ('1355', 'Isaac Caldeira', '071.462.938-31', 'isaac_718@dominio.com'),
#  ('1356', 'Luiza Santos', '937.681.045-75', 'luiza_459@dominio.com'),
#  ('1357', 'Catarina Pires', '247.935.810-05', 'catarina_394@dominio.com'),
#  ('1358', 'Rodrigo Cunha', '513.607.928-21', 'rodrigo_927@dominio.com'),
#  ('1359', 'Sr. Arthur Melo', '485.769.123-09', 'sr._992@dominio.com'),
#  ('136', 'Caio Rocha', '250.189.673-40', 'caio_360@dominio.com'),
#  ('1360', 'Maria Cecília Almeida', '910.485.362-89', 'maria_457@dominio.com'),
#  ('1361', 'Marcos Vinicius Melo', '973.108.625-03', 'marcos_706@dominio.com'),
#  ('1362', 'Maria Clara Duarte', '625.781.039-68', 'maria_465@dominio.com'),
#  ('1363', 'Ana Julia Cavalcanti', '573.246.019-52', 'ana_728@dominio.com'),
#  ('1364', 'Davi Luiz Aragão', '820.647.135-90', 'davi_907@dominio.com'),
#  ('1365', 'Carolina da Costa', '852.307.916-59', 'carolina_314@dominio.com'),
#  ('1366', 'Brenda Gomes', '415.089.673-93', 'brenda_986@dominio.com'),
#  ('1367', 'Manuela da Luz', '832.167.054-71', 'manuela_773@dominio.com'),
#  ('1368', 'Valentina Jesus', '192.568.470-94', 'valentina_155@dominio.com'),
#  ('1369', 'Dra. Nicole Araújo', '645.783.902-92', 'dra._762@dominio.com'),
#  ('137', 'Júlia Mendes', '468.297.105-02', 'júlia_740@dominio.com'),
#  ('1370',
#   'Maria Julia da Conceição',
#   '056.972.148-20',
#   'maria_404@dominio.com'),
#  ('1371', 'Maria Fernanda Porto', '350.279.816-86', 'maria_967@dominio.com'),
#  ('1372',
#   'Gustavo Henrique Monteiro',
#   '759.130.486-01',
#   'gustavo_960@dominio.com'),
#  ('1373', 'Srta. Heloísa Campos', '156.048.972-30', 'srta._196@dominio.com'),
#  ('1374', 'Srta. Clara Vieira', '106.473.259-34', 'srta._190@dominio.com'),
#  ('1375', 'Maria Luiza Barros', '678.259.304-10', 'maria_957@dominio.com'),
#  ('1376', 'Sra. Maria Clara Silva', '346.905.827-00', 'sra._431@dominio.com'),
#  ('1377', 'Dr. Joaquim Rodrigues', '859.207.641-20', 'dr._604@dominio.com'),
#  ('1378', 'Melissa Carvalho', '305.846.791-57', 'melissa_492@dominio.com'),
#  ('1379', 'Dr. Emanuel Porto', '274.365.098-29', 'dr._821@dominio.com'),
#  ('138', 'Sr. Anthony Correia', '614.570.983-93', 'sr._705@dominio.com'),
#  ('1380', 'Laura das Neves', '320.948.561-51', 'laura_792@dominio.com'),
#  ('1381', 'Sra. Rebeca Dias', '154.936.802-89', 'sra._467@dominio.com'),
#  ('1382', 'Luiz Felipe Almeida', '946.135.870-93', 'luiz_114@dominio.com'),
#  ('1383', 'Sr. Murilo Vieira', '491.782.365-09', 'sr._404@dominio.com'),
#  ('1384', 'Sr. Luiz Otávio Campos', '630.849.571-93', 'sr._461@dominio.com'),
#  ('1385', 'Lucas Gabriel Dias', '351.068.492-33', 'lucas_884@dominio.com'),
#  ('1386', 'Kamilly Nogueira', '296.741.853-64', 'kamilly_560@dominio.com'),
#  ('1387', 'João Teixeira', '167.490.523-80', 'joão_781@dominio.com'),
#  ('1388', 'Bruna da Mata', '489.137.602-31', 'bruna_395@dominio.com'),
#  ('1389', 'Kevin das Neves', '154.863.720-35', 'kevin_124@dominio.com'),
#  ('139', 'Vitor Hugo Costela', '897.130.462-69', 'vitor_374@dominio.com'),
#  ('1390', 'Eduarda Gomes', '378.269.415-55', 'eduarda_967@dominio.com'),
#  ('1391', 'Benjamin Viana', '528.603.174-90', 'benjamin_962@dominio.com'),
#  ('1392', 'Rebeca Gomes', '648.729.501-94', 'rebeca_586@dominio.com'),
#  ('1393', 'Gustavo da Rocha', '918.534.670-57', 'gustavo_780@dominio.com'),
#  ('1394',
#   'Henrique da Conceição',
#   '127.948.650-30',
#   'henrique_142@dominio.com'),
#  ('1395', 'Dr. Vicente Sales', '835.749.612-19', 'dr._706@dominio.com'),
#  ('1396', 'Ana Lívia Melo', '934.720.851-50', 'ana_485@dominio.com'),
#  ('1397', 'Pedro Henrique Campos', '639.124.085-05', 'pedro_779@dominio.com'),
#  ('1398', 'Emilly Cunha', '015.879.246-76', 'emilly_471@dominio.com'),
#  ('1399', 'Eloah Gonçalves', '430.172.968-22', 'eloah_111@dominio.com'),
#  ('14', 'Evelyn Teixeira', '359.872.614-73', 'evelyn_614@dominio.com'),
#  ('140', 'Thales da Cruz', '432.109.687-13', 'thales_169@dominio.com'),
#  ('1400',
#   'Srta. Maria Fernanda Aragão',
#   '451.362.970-34',
#   'srta._200@dominio.com'),
#  ('1401', 'Maria Luiza Rodrigues', '358.617.420-90', 'maria_726@dominio.com'),
#  ('1402', 'Mirella da Rosa', '165.784.029-85', 'mirella_302@dominio.com'),
#  ('1403', 'Maria Julia Moura', '432.507.168-71', 'maria_245@dominio.com'),
#  ('1404', 'Melissa Campos', '013.876.452-26', 'melissa_584@dominio.com'),
#  ('1405', 'Felipe Moura', '974.082.631-87', 'felipe_787@dominio.com'),
#  ('1406',
#   'Dr. João Guilherme Monteiro',
#   '237.901.645-34',
#   'dr._964@dominio.com'),
#  ('1407', 'Davi Luiz Moreira', '204.598.613-60', 'davi_162@dominio.com'),
#  ('1408',
#   'Dr. Luiz Henrique Silveira',
#   '673.104.982-40',
#   'dr._668@dominio.com'),
#  ('1409', 'Luigi Costela', '079.841.265-85', 'luigi_890@dominio.com'),
#  ('141', 'Ana Lívia Melo', '124.576.098-01', 'ana_235@dominio.com'),
#  ('1410', 'Daniel Jesus', '467.850.139-84', 'daniel_547@dominio.com'),
#  ('1411', 'Giovanna Moreira', '586.349.071-39', 'giovanna_647@dominio.com'),
#  ('1412', 'Sra. Laís Silveira', '659.201.348-60', 'sra._355@dominio.com'),
#  ('1413',
#   'Carolina da Conceição',
#   '268.540.137-71',
#   'carolina_705@dominio.com'),
#  ('1414', 'Lucas Gabriel Jesus', '347.510.682-53', 'lucas_355@dominio.com'),
#  ('1415', 'João Felipe Dias', '390.876.124-78', 'joão_525@dominio.com'),
#  ('1416',
#   'Sr. João Gabriel Nascimento',
#   '638.250.917-59',
#   'sr._366@dominio.com'),
#  ('1417', 'Thales Peixoto', '153.807.642-07', 'thales_168@dominio.com'),
#  ('1418', 'Olivia Teixeira', '534.710.829-05', 'olivia_172@dominio.com'),
#  ('1419', 'Sr. Lucca da Rosa', '934.807.615-93', 'sr._300@dominio.com'),
#  ('142', 'Davi Luiz da Cunha', '690.385.471-10', 'davi_297@dominio.com'),
#  ('1420', 'Rodrigo Sales', '126.450.938-33', 'rodrigo_584@dominio.com'),
#  ('1421', 'Sra. Helena Cunha', '083.469.751-39', 'sra._129@dominio.com'),
#  ('1422', 'Dr. Matheus Farias', '059.123.867-59', 'dr._899@dominio.com'),
#  ('1423', 'Pietro Aragão', '593.826.071-02', 'pietro_205@dominio.com'),
#  ('1424', 'João Felipe Alves', '374.106.982-50', 'joão_119@dominio.com'),
#  ('1425', 'Pedro Henrique Novaes', '204.189.735-04', 'pedro_226@dominio.com'),
#  ('1426',
#   'Marcos Vinicius da Cunha',
#   '160.794.382-40',
#   'marcos_244@dominio.com'),
#  ('1427', 'Thiago Ferreira', '506.249.178-94', 'thiago_455@dominio.com'),
#  ('1428', 'Raquel Costela', '053.824.971-41', 'raquel_271@dominio.com'),
#  ('1429', 'Maria Clara Souza', '953.726.810-12', 'maria_687@dominio.com'),
#  ('143', 'Natália da Conceição', '469.518.237-82', 'natália_657@dominio.com'),
#  ('1430', 'Sra. Isabel Rodrigues', '786.231.095-03', 'sra._227@dominio.com'),
#  ('1431', 'Ana Sophia da Costa', '268.739.451-37', 'ana_303@dominio.com'),
#  ('1432', 'Maria Fernanda Campos', '805.319.476-10', 'maria_862@dominio.com'),
#  ('1433', 'Davi Luiz Correia', '206.458.791-85', 'davi_268@dominio.com'),
#  ('1434', 'Davi Lima', '148.657.302-90', 'davi_909@dominio.com'),
#  ('1435', 'Ana Laura Nogueira', '397.514.608-75', 'ana_139@dominio.com'),
#  ('1436', 'Dr. Marcelo Barbosa', '306.928.451-51', 'dr._571@dominio.com'),
#  ('1437', 'Dr. Francisco Melo', '317.052.649-99', 'dr._194@dominio.com'),
#  ('1438', 'Maria Alice Aragão', '059.621.473-16', 'maria_180@dominio.com'),
#  ('1439', 'Alice Ferreira', '510.287.436-53', 'alice_466@dominio.com'),
#  ('144', 'Heloísa Farias', '124.973.568-82', 'heloísa_594@dominio.com'),
#  ('1440', 'Dr. Enzo Nogueira', '095.812.376-40', 'dr._271@dominio.com'),
#  ('1441', 'Ana Sophia Castro', '876.021.594-11', 'ana_752@dominio.com'),
#  ('1442', 'Ana Júlia da Cunha', '829.501.734-97', 'ana_753@dominio.com'),
#  ('1443', 'Fernanda da Cunha', '815.279.304-32', 'fernanda_477@dominio.com'),
#  ('1444', 'Caroline Nogueira', '284.730.956-00', 'caroline_919@dominio.com'),
#  ('1445', 'Bruna Farias', '413.925.860-89', 'bruna_454@dominio.com'),
#  ('1446', 'Lucas Rodrigues', '872.946.531-19', 'lucas_752@dominio.com'),
#  ('1447', 'Ana Lívia Moura', '916.278.053-03', 'ana_658@dominio.com'),
#  ('1448', 'João Gabriel Aragão', '984.065.713-57', 'joão_777@dominio.com'),
#  ('1449', 'Clara da Paz', '980.542.361-15', 'clara_943@dominio.com'),
#  ('145', 'Nina Fernandes', '720.651.384-08', 'nina_171@dominio.com'),
#  ('1450',
#   'Maria Fernanda Nascimento',
#   '342.085.916-33',
#   'maria_393@dominio.com'),
#  ('1451', 'Maria Sophia Dias', '694.871.520-67', 'maria_258@dominio.com'),
#  ('1452', 'Clarice Gomes', '951.738.240-50', 'clarice_311@dominio.com'),
#  ('1453', 'Sr. Noah Silveira', '610.972.438-69', 'sr._353@dominio.com'),
#  ('1454', 'Maria Eduarda Teixeira', '214.958.037-32', 'maria_904@dominio.com'),
#  ('1455', 'Srta. Brenda Souza', '124.780.359-79', 'srta._218@dominio.com'),
#  ('1456', 'Luiz Fernando Vieira', '609.214.537-52', 'luiz_931@dominio.com'),
#  ('1457', 'Melissa Pinto', '279.341.068-31', 'melissa_977@dominio.com'),
#  ('1458', 'Gabrielly Souza', '253.961.074-99', 'gabrielly_944@dominio.com'),
#  ('1459', 'Cauã Pereira', '375.982.461-73', 'cauã_852@dominio.com'),
#  ('146', 'Marcela Viana', '296.718.053-02', 'marcela_132@dominio.com'),
#  ('1460', 'Ryan Gomes', '416.530.972-99', 'ryan_747@dominio.com'),
#  ('1461', 'Joaquim Moraes', '653.492.078-65', 'joaquim_748@dominio.com'),
#  ('1462', 'Davi Lucas Pinto', '087.461.329-96', 'davi_383@dominio.com'),
#  ('1463',
#   'Sr. Gustavo Henrique Teixeira',
#   '497.203.815-23',
#   'sr._191@dominio.com'),
#  ('1464', 'Laís Moreira', '159.843.072-60', 'laís_610@dominio.com'),
#  ('1465', 'Cauã da Paz', '580.236.917-59', 'cauã_633@dominio.com'),
#  ('1466', 'Fernando Ferreira', '145.709.368-57', 'fernando_395@dominio.com'),
#  ('1467', 'Pedro Miguel Silva', '026.748.359-74', 'pedro_627@dominio.com'),
#  ('1468', 'Emilly Azevedo', '594.821.036-70', 'emilly_241@dominio.com'),
#  ('1469', 'Thiago Lopes', '439.815.607-01', 'thiago_243@dominio.com'),
#  ('147', 'Dr. Pedro Vieira', '094.718.563-10', 'dr._630@dominio.com'),
#  ('1470', 'Dra. Gabrielly Costela', '539.612.870-40', 'dra._287@dominio.com'),
#  ('1471', 'Benício Jesus', '687.293.401-87', 'benício_347@dominio.com'),
#  ('1472', 'Eduarda Carvalho', '403.127.695-80', 'eduarda_427@dominio.com'),
#  ('1473', 'Benjamin Moreira', '406.293.785-92', 'benjamin_814@dominio.com'),
#  ('1474', 'Eduarda Teixeira', '897.135.246-91', 'eduarda_747@dominio.com'),
#  ('1475', 'Caio Santos', '860.471.359-00', 'caio_833@dominio.com'),
#  ('1476', 'Eduarda da Paz', '805.614.372-62', 'eduarda_415@dominio.com'),
#  ('1477', 'Noah Costela', '745.903.618-84', 'noah_666@dominio.com'),
#  ('1478', 'Dr. Ian da Paz', '269.418.530-42', 'dr._234@dominio.com'),
#  ('1479', 'Bruno da Cruz', '913.206.754-25', 'bruno_124@dominio.com'),
#  ('148', 'Melissa Castro', '368.107.294-96', 'melissa_801@dominio.com'),
#  ('1480', 'Joana Viana', '546.320.187-08', 'joana_655@dominio.com'),
#  ('1481', 'Raul Lima', '403.295.178-05', 'raul_733@dominio.com'),
#  ('1482', 'Levi da Paz', '463.285.170-17', 'levi_120@dominio.com'),
#  ('1483', 'João Gabriel Cunha', '751.649.830-01', 'joão_851@dominio.com'),
#  ('1484', 'Luiz Felipe Ribeiro', '910.386.247-03', 'luiz_246@dominio.com'),
#  ('1485', 'Emanuelly Barbosa', '690.872.354-29', 'emanuelly_601@dominio.com'),
#  ('1486', 'Erick Pires', '463.791.028-50', 'erick_192@dominio.com'),
#  ('1487', 'Calebe Caldeira', '295.374.816-46', 'calebe_326@dominio.com'),
#  ('1488', 'Fernanda Farias', '024.695.871-58', 'fernanda_501@dominio.com'),
#  ('1489', 'Pedro Henrique Vieira', '059.324.618-70', 'pedro_884@dominio.com'),
#  ('149', 'Maria Sophia Cardoso', '254.068.371-17', 'maria_342@dominio.com'),
#  ('1490', 'Lívia das Neves', '149.508.376-48', 'lívia_908@dominio.com'),
#  ('1491', 'Sr. Bernardo Freitas', '795.413.286-28', 'sr._492@dominio.com'),
#  ('1492', 'Dr. Davi Santos', '207.631.854-26', 'dr._387@dominio.com'),
#  ('1493', 'Renan Silveira', '812.795.463-28', 'renan_755@dominio.com'),
#  ('1494', 'Dr. Yuri Campos', '217.638.049-50', 'dr._613@dominio.com'),
#  ('1495', 'Sra. Raquel Rezende', '698.714.035-93', 'sra._952@dominio.com'),
#  ('1496', 'Pedro Lucas da Cunha', '862.374.051-35', 'pedro_252@dominio.com'),
#  ('1497', 'Raquel Pinto', '165.973.408-84', 'raquel_574@dominio.com'),
#  ('1498', 'Dra. Luna Alves', '806.194.235-60', 'dra._637@dominio.com'),
#  ('1499', 'Larissa Teixeira', '203.687.954-38', 'larissa_156@dominio.com'),
#  ('15', 'Sophie Rocha', '670.421.598-02', 'sophie_737@dominio.com'),
#  ('150', 'Theo Rocha', '421.689.705-30', 'theo_942@dominio.com'),
#  ('1500', 'Laura Duarte', '318.704.592-88', 'laura_749@dominio.com'),
#  ('1501', 'Natália Duarte', '536.179.408-20', 'natália_666@dominio.com'),
#  ('1502', 'Maria Alice da Rocha', '063.279.514-06', 'maria_765@dominio.com'),
#  ('1503', 'Kaique Ramos', '429.165.708-02', 'kaique_106@dominio.com'),
#  ('1504', 'Murilo Cunha', '731.648.052-17', 'murilo_786@dominio.com'),
#  ('1505', 'Vinicius Nascimento', '142.786.395-46', 'vinicius_945@dominio.com'),
#  ('1506', 'João Guilherme Jesus', '135.927.064-70', 'joão_587@dominio.com'),
#  ('1507', 'Srta. Helena da Rosa', '501.378.692-40', 'srta._768@dominio.com'),
#  ('1508', 'Laís da Costa', '386.750.194-75', 'laís_413@dominio.com'),
#  ('1509', 'Manuela da Cunha', '529.031.746-52', 'manuela_644@dominio.com'),
#  ('151', 'Sophia Barbosa', '603.485.791-01', 'sophia_852@dominio.com'),
#  ('1510', 'Nicole Farias', '032.879.645-00', 'nicole_648@dominio.com'),
#  ('1511', 'Isaac Mendes', '350.976.412-99', 'isaac_198@dominio.com'),
#  ('1512', 'Joaquim Cardoso', '601.743.985-57', 'joaquim_342@dominio.com'),
#  ('1513', 'Srta. Juliana Silva', '047.129.683-03', 'srta._227@dominio.com'),
#  ('1514', 'Renan Ramos', '564.192.783-09', 'renan_345@dominio.com'),
#  ('1515', 'Sr. Augusto Cavalcanti', '534.162.890-05', 'sr._348@dominio.com'),
#  ('1516', 'Daniela Moraes', '958.640.123-51', 'daniela_842@dominio.com'),
#  ('1517', 'Gabrielly Nogueira', '589.341.627-91', 'gabrielly_795@dominio.com'),
#  ('1518', 'Murilo Sales', '439.082.165-24', 'murilo_704@dominio.com'),
#  ('1519', 'Benjamin Nunes', '741.096.835-48', 'benjamin_725@dominio.com'),
#  ('152', 'Eloah Cavalcanti', '185.379.640-93', 'eloah_845@dominio.com'),
#  ('1520', 'Ana Laura Barbosa', '128.093.547-23', 'ana_229@dominio.com'),
#  ('1521', 'Bryan Rocha', '815.409.627-76', 'bryan_530@dominio.com'),
#  ('1522', 'Ana Laura Caldeira', '316.702.598-03', 'ana_477@dominio.com'),
#  ('1523', 'Rafael Araújo', '489.570.126-30', 'rafael_852@dominio.com'),
#  ('1524', 'Dr. Bryan Rodrigues', '482.137.059-04', 'dr._209@dominio.com'),
#  ('1525', 'Bryan Cunha', '409.631.872-87', 'bryan_951@dominio.com'),
#  ('1526', 'João Vitor da Paz', '914.385.206-89', 'joão_340@dominio.com'),
#  ('1527', 'Juan Gonçalves', '961.742.035-06', 'juan_954@dominio.com'),
#  ('1528', 'Manuela das Neves', '572.384.169-64', 'manuela_574@dominio.com'),
#  ('1529', 'Olivia Costa', '396.854.721-73', 'olivia_601@dominio.com'),
#  ('153', 'Sofia Novaes', '362.017.984-04', 'sofia_586@dominio.com'),
#  ('1530', 'Luiz Miguel Novaes', '529.871.406-49', 'luiz_668@dominio.com'),
#  ('1531', 'Dr. Joaquim Mendes', '674.581.302-53', 'dr._658@dominio.com'),
#  ('1532', 'Elisa Pereira', '964.018.532-98', 'elisa_544@dominio.com'),
#  ('1533', 'Isabella Carvalho', '263.784.059-56', 'isabella_311@dominio.com'),
#  ('1534', 'Rafaela Novaes', '561.478.902-20', 'rafaela_581@dominio.com'),
#  ('1535', 'Augusto Melo', '793.841.526-09', 'augusto_929@dominio.com'),
#  ('1536', 'Ana Júlia da Mota', '490.231.568-89', 'ana_152@dominio.com'),
#  ('1537', 'Gustavo Araújo', '357.426.918-82', 'gustavo_767@dominio.com'),
#  ('1538', 'Natália Lima', '896.405.723-65', 'natália_669@dominio.com'),
#  ('1539', 'Elisa Costa', '251.876.049-02', 'elisa_420@dominio.com'),
#  ('154', 'João Lucas Freitas', '352.694.801-15', 'joão_344@dominio.com'),
#  ('1540', 'Danilo Pinto', '645.208.391-06', 'danilo_281@dominio.com'),
#  ('1541', 'Camila Freitas', '805.971.423-60', 'camila_279@dominio.com'),
#  ('1542', 'Enzo da Rosa', '723.985.016-12', 'enzo_355@dominio.com'),
#  ('1543', 'Maria Luiza Lopes', '724.689.105-67', 'maria_742@dominio.com'),
#  ('1544', 'Ana Beatriz Nogueira', '215.467.039-34', 'ana_146@dominio.com'),
#  ('1545', 'Clarice da Luz', '640.238.517-44', 'clarice_605@dominio.com'),
#  ('1546', 'Pietro Gomes', '830.495.761-20', 'pietro_812@dominio.com'),
#  ('1547', 'Mariana Duarte', '163.940.782-04', 'mariana_426@dominio.com'),
#  ('1548', 'Dra. Clarice Costa', '927.865.431-00', 'dra._978@dominio.com'),
#  ('1549', 'Antônio da Paz', '486.375.012-90', 'antônio_605@dominio.com'),
#  ('155', 'Matheus Moreira', '452.907.638-56', 'matheus_961@dominio.com'),
#  ('1550', 'Sr. Gabriel Cardoso', '920.876.531-86', 'sr._423@dominio.com'),
#  ('1551', 'Ian Cardoso', '159.608.342-51', 'ian_115@dominio.com'),
#  ('1552', 'Rafael Silveira', '026.415.973-06', 'rafael_228@dominio.com'),
#  ('1553', 'Lucas Lima', '357.042.819-23', 'lucas_804@dominio.com'),
#  ('1554', 'Pedro Lucas Lima', '319.546.802-60', 'pedro_968@dominio.com'),
#  ('1555', 'Heloísa Jesus', '017.823.645-44', 'heloísa_294@dominio.com'),
#  ('1556', 'Larissa da Cruz', '903.162.748-87', 'larissa_802@dominio.com'),
#  ('1557', 'Leandro Pires', '237.816.094-13', 'leandro_835@dominio.com'),
#  ('1558', 'Levi Martins', '470.958.631-48', 'levi_104@dominio.com'),
#  ('1559', 'João Vitor Costela', '526.079.384-65', 'joão_278@dominio.com'),
#  ('156', 'Maria Eduarda da Mota', '260.897.145-85', 'maria_320@dominio.com'),
#  ('1560', 'João Lucas da Mata', '453.819.062-42', 'joão_838@dominio.com'),
#  ('1561', 'Beatriz Caldeira', '534.761.028-07', 'beatriz_753@dominio.com'),
#  ('1562', 'Dra. Sabrina Souza', '436.801.259-33', 'dra._786@dominio.com'),
#  ('1563', 'Sr. Nicolas das Neves', '135.784.629-00', 'sr._254@dominio.com'),
#  ('1564', 'Sr. Luiz Miguel Jesus', '231.874.906-03', 'sr._856@dominio.com'),
#  ('1565', 'Stephany Pereira', '746.983.125-82', 'stephany_656@dominio.com'),
#  ('1566', 'Davi Lucas Fernandes', '601.839.472-31', 'davi_873@dominio.com'),
#  ('1567', 'Mirella Castro', '572.498.361-37', 'mirella_986@dominio.com'),
#  ('1568', 'João Miguel Araújo', '823.590.176-59', 'joão_297@dominio.com'),
#  ('1569', 'Stephany Peixoto', '671.302.984-13', 'stephany_269@dominio.com'),
#  ('157', 'Eduarda da Cunha', '895.372.046-00', 'eduarda_609@dominio.com'),
#  ('1570', 'Bruno Pereira', '319.528.067-12', 'bruno_749@dominio.com'),
#  ('1571', 'Dr. Pedro Miguel Cunha', '317.526.894-37', 'dr._431@dominio.com'),
#  ('1572', 'Vitor Hugo Rezende', '264.038.597-65', 'vitor_928@dominio.com'),
#  ('1573', 'Isabella da Cruz', '547.261.083-44', 'isabella_895@dominio.com'),
#  ('1574', 'Benício Porto', '012.659.748-02', 'benício_399@dominio.com'),
#  ('1575', 'Vinicius Castro', '218.435.960-24', 'vinicius_617@dominio.com'),
#  ('1576', 'Dr. João Guilherme Dias', '819.734.602-03', 'dr._264@dominio.com'),
#  ('1577', 'João Vitor Souza', '954.671.082-20', 'joão_517@dominio.com'),
#  ('1578', 'Diogo da Rosa', '816.340.925-89', 'diogo_754@dominio.com'),
#  ('1579', 'Theo Nunes', '615.073.984-84', 'theo_302@dominio.com'),
# ...
#  ('1704', 'Isabel Lima', '729.845.310-60', 'isabel_442@dominio.com'),
#  ('1705', 'Dra. Ana da Cruz', '198.357.640-93', 'dra._982@dominio.com'),
#  ('1706',
#   'Gustavo Henrique Aragão',
#   '053.891.267-77',
#   'gustavo_571@dominio.com'),
#  ('1707', 'Laura Santos', '370.891.642-50', 'laura_123@dominio.com'),
#  ('1708', 'Larissa Lopes', '406.735.298-00', 'larissa_599@dominio.com'),
#  ('1709', 'Bruno da Costa', '127.806.395-12', 'bruno_920@dominio.com'),
#  ('171', 'Sr. Bryan Dias', '589.317.064-48', 'sr._433@dominio.com'),
#  ('1710',
#   'Srta. Maria Julia Carvalho',
#   '876.514.390-66',
#   'srta._304@dominio.com'),
#  ('1711', 'Davi Lucca Lima', '752.869.143-73', 'davi_453@dominio.com'),
#  ('1712', 'Isabel Silveira', '182.397.640-96', 'isabel_677@dominio.com'),
#  ('1713', 'Sophia Lima', '971.302.845-79', 'sophia_795@dominio.com'),
#  ('1714', 'Natália Cunha', '394.876.510-39', 'natália_607@dominio.com'),
#  ('1715', 'Mirella Nascimento', '738.125.649-55', 'mirella_619@dominio.com'),
#  ('1716', 'Dr. Luiz Miguel Dias', '269.841.305-06', 'dr._555@dominio.com'),
#  ('1717', 'Thomas Campos', '914.023.658-70', 'thomas_802@dominio.com'),
#  ('1718', 'Felipe Santos', '148.967.352-00', 'felipe_721@dominio.com'),
#  ('1719', 'Giovanna Pires', '439.718.250-79', 'giovanna_827@dominio.com'),
#  ('172', 'Davi Lucas Freitas', '765.918.340-01', 'davi_441@dominio.com'),
#  ('1720', 'Dr. Gustavo Nogueira', '843.059.761-10', 'dr._303@dominio.com'),
#  ('1721', 'Srta. Beatriz Duarte', '065.281.379-86', 'srta._719@dominio.com'),
#  ('1722', 'Diogo Pinto', '609.457.132-07', 'diogo_953@dominio.com'),
#  ('1723', 'Vitor Hugo Silveira', '963.018.724-87', 'vitor_170@dominio.com'),
#  ('1724', 'Natália Carvalho', '590.231.486-06', 'natália_163@dominio.com'),
#  ('1725', 'Alice Freitas', '614.593.082-98', 'alice_408@dominio.com'),
#  ('1726', 'André Cunha', '186.539.724-55', 'andré_586@dominio.com'),
#  ('1727', 'Benjamin Carvalho', '148.237.905-88', 'benjamin_137@dominio.com'),
#  ('1728', 'Bianca Gomes', '406.327.195-16', 'bianca_549@dominio.com'),
#  ('1729', 'Theo Santos', '701.235.496-80', 'theo_474@dominio.com'),
#  ('173', 'Yago Freitas', '290.461.873-22', 'yago_222@dominio.com'),
#  ('1730', 'Mariana Jesus', '136.984.205-89', 'mariana_757@dominio.com'),
#  ('1731', 'Isabelly da Rosa', '523.648.901-60', 'isabelly_939@dominio.com'),
#  ('1732', 'Amanda Cardoso', '837.659.241-64', 'amanda_290@dominio.com'),
#  ('1733', 'Heitor Pinto', '230.576.489-83', 'heitor_806@dominio.com'),
#  ('1734', 'Stephany Mendes', '105.974.286-11', 'stephany_236@dominio.com'),
#  ('1735', 'Anthony Ramos', '874.369.015-75', 'anthony_828@dominio.com'),
#  ('1736', 'Cauã Costa', '406.859.372-83', 'cauã_290@dominio.com'),
#  ('1737', 'Ana Beatriz das Neves', '631.708.425-44', 'ana_209@dominio.com'),
#  ('1738', 'Maria Alice Melo', '523.690.841-89', 'maria_660@dominio.com'),
#  ('1739', 'Emilly Moraes', '423.690.781-03', 'emilly_669@dominio.com'),
#  ('174', 'Laís Ferreira', '839.654.071-39', 'laís_920@dominio.com'),
#  ('1740', 'Pedro Miguel Rodrigues', '283.175.940-41', 'pedro_301@dominio.com'),
#  ('1741', 'Srta. Amanda da Rosa', '537.961.804-93', 'srta._516@dominio.com'),
#  ('1742', 'Srta. Lara Silva', '481.207.936-50', 'srta._597@dominio.com'),
#  ('1743', 'João Pedro Costela', '379.862.145-46', 'joão_656@dominio.com'),
#  ('1744', 'Alana Monteiro', '340.276.189-04', 'alana_520@dominio.com'),
#  ('1745', 'Srta. Ana Jesus', '157.432.690-25', 'srta._243@dominio.com'),
#  ('1746', 'Sr. Juan Almeida', '265.789.013-02', 'sr._450@dominio.com'),
#  ('1747', 'Luiz Fernando Farias', '762.813.409-22', 'luiz_751@dominio.com'),
#  ('1748', 'Lucas Gomes', '832.069.714-03', 'lucas_807@dominio.com'),
#  ('1749', 'Felipe Cunha', '053.918.647-39', 'felipe_473@dominio.com'),
#  ('175', 'Gabriela da Mata', '385.720.164-90', 'gabriela_162@dominio.com'),
#  ('1750', 'Nathan Moreira', '936.425.807-00', 'nathan_928@dominio.com'),
#  ('1751', 'Alícia Moura', '129.648.507-20', 'alícia_315@dominio.com'),
#  ('1752', 'Eduarda Fogaça', '024.971.538-41', 'eduarda_429@dominio.com'),
#  ('1753', 'Dr. Calebe Campos', '067.824.159-76', 'dr._653@dominio.com'),
#  ('1754', 'Gabriel Souza', '914.706.382-31', 'gabriel_399@dominio.com'),
#  ('1755', 'Joana Moraes', '094.327.568-74', 'joana_710@dominio.com'),
#  ('1756', 'Diego da Cruz', '418.379.506-01', 'diego_305@dominio.com'),
#  ('1757', 'Levi Rezende', '967.382.041-40', 'levi_342@dominio.com'),
#  ('1758', 'Sarah Ferreira', '089.537.621-03', 'sarah_629@dominio.com'),
#  ('1759', 'Dr. Fernando Pinto', '629.713.450-25', 'dr._860@dominio.com'),
#  ('176', 'Ana Clara Moraes', '954.326.107-52', 'ana_272@dominio.com'),
#  ('1760', 'Clarice Moraes', '964.253.187-91', 'clarice_473@dominio.com'),
#  ('1761', 'Marcos Vinicius Pires', '570.241.389-04', 'marcos_942@dominio.com'),
#  ('1762', 'Dr. Kaique Araújo', '542.910.763-80', 'dr._160@dominio.com'),
#  ('1763', 'Ana Carolina Mendes', '698.523.714-28', 'ana_759@dominio.com'),
#  ('1764', 'Natália Farias', '157.368.429-55', 'natália_100@dominio.com'),
#  ('1765', 'Dr. Kaique Moreira', '291.687.503-40', 'dr._978@dominio.com'),
#  ('1766', 'Sabrina Ramos', '895.731.602-77', 'sabrina_752@dominio.com'),
#  ('1767', 'Dra. Alana Moura', '154.963.072-52', 'dra._415@dominio.com'),
#  ('1768', 'Vitor da Mota', '283.104.596-70', 'vitor_277@dominio.com'),
#  ('1769', 'André Moraes', '876.520.439-56', 'andré_701@dominio.com'),
#  ('177', 'Raquel Carvalho', '470.126.389-31', 'raquel_655@dominio.com'),
#  ('1770',
#   'Srta. Sabrina Fernandes',
#   '976.518.302-02',
#   'srta._414@dominio.com'),
#  ('1771', 'Ana Clara Mendes', '471.260.953-25', 'ana_607@dominio.com'),
#  ('1772',
#   'Dr. Marcos Vinicius Castro',
#   '031.674.925-70',
#   'dr._248@dominio.com'),
#  ('1773', 'Ana Clara Correia', '742.601.839-31', 'ana_572@dominio.com'),
#  ('1774', 'Dr. Bruno Gonçalves', '014.297.853-14', 'dr._822@dominio.com'),
#  ('1775',
#   'Sr. Luiz Henrique Gonçalves',
#   '025.381.974-14',
#   'sr._258@dominio.com'),
#  ('1776', 'Eduardo Sales', '057.926.483-10', 'eduardo_765@dominio.com'),
#  ('1777', 'Lucas Gabriel Jesus', '904.673.258-47', 'lucas_961@dominio.com'),
#  ('1778', 'Emilly da Costa', '342.587.960-00', 'emilly_446@dominio.com'),
#  ('1779', 'Ana Vitória Barbosa', '167.582.039-21', 'ana_797@dominio.com'),
#  ('178', 'Lucas Correia', '302.541.867-26', 'lucas_924@dominio.com'),
#  ('1780', 'Maria da Rosa', '162.708.943-87', 'maria_576@dominio.com'),
#  ('1781', 'Francisco Souza', '316.089.254-98', 'francisco_928@dominio.com'),
#  ('1782', 'Dra. Maria Alice Nunes', '537.618.049-20', 'dra._779@dominio.com'),
#  ('1783', 'Maysa Nogueira', '743.168.209-31', 'maysa_931@dominio.com'),
#  ('1784', 'Rafaela Rocha', '203.471.689-22', 'rafaela_788@dominio.com'),
#  ('1785', 'Ana Lívia Almeida', '079.436.528-00', 'ana_347@dominio.com'),
#  ('1786', 'Maria Julia Silva', '720.514.983-50', 'maria_818@dominio.com'),
#  ('1787', 'Rafael Pereira', '051.982.367-21', 'rafael_258@dominio.com'),
#  ('1788', 'Pietra Silva', '718.950.463-00', 'pietra_121@dominio.com'),
#  ('1789', 'Theo Campos', '693.582.017-03', 'theo_143@dominio.com'),
#  ('179', 'Clarice Nunes', '498.516.372-46', 'clarice_571@dominio.com'),
#  ('1790', 'Ana Sophia Barros', '236.047.185-62', 'ana_826@dominio.com'),
#  ('1791', 'Maria Vitória Lima', '124.905.673-06', 'maria_751@dominio.com'),
#  ('1792', 'Joaquim Ribeiro', '105.764.982-11', 'joaquim_871@dominio.com'),
#  ('1793', 'Julia Viana', '240.138.756-08', 'julia_213@dominio.com'),
#  ('1794', 'Ana Julia da Costa', '695.423.108-89', 'ana_127@dominio.com'),
#  ('1795', 'Maria Sophia Sales', '342.178.059-50', 'maria_974@dominio.com'),
#  ('1796', 'Raul Teixeira', '732.165.409-52', 'raul_998@dominio.com'),
#  ('1797', 'Luiz Henrique Silva', '162.948.350-89', 'luiz_918@dominio.com'),
#  ('1798', 'Stella da Mota', '813.576.042-62', 'stella_602@dominio.com'),
#  ('1799', 'Agatha Pires', '543.092.871-23', 'agatha_499@dominio.com'),
#  ('18', 'Emanuelly Cardoso', '784.152.063-80', 'emanuelly_496@dominio.com'),
#  ('180', 'Yago das Neves', '150.472.398-88', 'yago_445@dominio.com'),
#  ('1800', 'Stella Azevedo', '618.427.039-78', 'stella_316@dominio.com'),
#  ('1801', 'Davi Lucas Cunha', '765.280.341-17', 'davi_196@dominio.com'),
#  ('1802', 'Lucas Gabriel Moreira', '789.316.042-03', 'lucas_533@dominio.com'),
#  ('1803', 'Bianca Barbosa', '935.267.041-80', 'bianca_457@dominio.com'),
#  ('1804', 'Benício Aragão', '705.192.436-25', 'benício_237@dominio.com'),
#  ('1805', 'Heloísa Martins', '128.679.405-67', 'heloísa_815@dominio.com'),
#  ('1806', 'Joaquim da Rocha', '401.325.798-04', 'joaquim_749@dominio.com'),
#  ('1807', 'Sr. Vinicius Mendes', '765.314.928-64', 'sr._543@dominio.com'),
#  ('1808', 'Benício Cardoso', '058.716.432-80', 'benício_330@dominio.com'),
#  ('1809', 'Kaique Cardoso', '907.632.541-34', 'kaique_268@dominio.com'),
#  ('181', 'Fernando Pires', '569.023.478-83', 'fernando_245@dominio.com'),
#  ('1810', 'Leonardo Sales', '908.163.527-12', 'leonardo_532@dominio.com'),
#  ('1811', 'João Farias', '849.320.517-60', 'joão_864@dominio.com'),
#  ('1812', 'Heitor Cavalcanti', '790.634.512-61', 'heitor_638@dominio.com'),
#  ('1813', 'Stella Pinto', '510.628.347-71', 'stella_973@dominio.com'),
#  ('1814', 'Francisco Cardoso', '234.980.176-40', 'francisco_264@dominio.com'),
#  ('1815', 'Enzo Gabriel Caldeira', '425.109.786-67', 'enzo_361@dominio.com'),
#  ('1816', 'Francisco Caldeira', '238.974.510-50', 'francisco_710@dominio.com'),
#  ('1817', 'Natália Moreira', '942.081.573-05', 'natália_502@dominio.com'),
#  ('1818', 'Eduardo Aragão', '930.741.286-31', 'eduardo_152@dominio.com'),
#  ('1819', 'Maria Fernanda Rocha', '756.319.028-77', 'maria_859@dominio.com'),
#  ('182', 'Emanuel Peixoto', '653.974.802-74', 'emanuel_540@dominio.com'),
#  ('1820', 'Maria Cecília Rocha', '819.463.257-91', 'maria_318@dominio.com'),
#  ('1821', 'Maria Alice da Paz', '403.812.967-50', 'maria_185@dominio.com'),
#  ('1822', 'Melissa Dias', '138.607.429-22', 'melissa_552@dominio.com'),
#  ('1823', 'Ana Júlia Costa', '295.746.103-06', 'ana_386@dominio.com'),
#  ('1824', 'Maria Luiza Cunha', '264.308.957-00', 'maria_543@dominio.com'),
#  ('1825', 'Davi Luiz da Costa', '476.258.109-76', 'davi_144@dominio.com'),
#  ('1826', 'Evelyn Cavalcanti', '794.526.381-09', 'evelyn_195@dominio.com'),
#  ('1827', 'Julia da Conceição', '436.802.917-87', 'julia_745@dominio.com'),
#  ('1828', 'Sr. Nathan Silveira', '196.475.830-01', 'sr._707@dominio.com'),
#  ('1829',
#   'Dra. Maria Sophia Peixoto',
#   '538.964.710-66',
#   'dra._173@dominio.com'),
#  ('183', 'Maria Alice Cardoso', '986.321.047-13', 'maria_910@dominio.com'),
#  ('1830', 'Bryan Souza', '409.173.562-25', 'bryan_677@dominio.com'),
#  ('1831', 'Daniel da Cruz', '765.298.314-28', 'daniel_592@dominio.com'),
#  ('1832', 'Maitê Barbosa', '279.614.308-22', 'maitê_973@dominio.com'),
#  ('1833',
#   'Gustavo Henrique da Cunha',
#   '487.530.169-39',
#   'gustavo_780@dominio.com'),
#  ('1834', 'Thiago da Mota', '018.269.354-60', 'thiago_490@dominio.com'),
#  ('1835', 'João Vitor da Mata', '076.945.812-20', 'joão_963@dominio.com'),
#  ('1836', 'Larissa da Costa', '965.821.374-09', 'larissa_765@dominio.com'),
#  ('1837', 'Heitor Cavalcanti', '216.730.598-21', 'heitor_797@dominio.com'),
#  ('1838', 'Stella Pires', '874.632.905-65', 'stella_199@dominio.com'),
#  ('1839', 'Dr. Marcelo Pinto', '613.052.749-70', 'dr._519@dominio.com'),
#  ('184', 'Catarina Fogaça', '908.723.514-32', 'catarina_877@dominio.com'),
#  ('1840', 'Laís Lima', '503.218.467-53', 'laís_712@dominio.com'),
#  ('1841', 'Isabelly Viana', '342.786.105-80', 'isabelly_114@dominio.com'),
#  ('1842', 'Ana Cavalcanti', '851.609.324-70', 'ana_825@dominio.com'),
#  ('1843', 'Pedro Lucas da Rosa', '723.695.804-29', 'pedro_229@dominio.com'),
#  ('1844', 'Sra. Amanda Souza', '742.910.356-16', 'sra._499@dominio.com'),
#  ('1845', 'Cecília Almeida', '681.790.543-57', 'cecília_807@dominio.com'),
#  ('1846', 'Maria Julia Sales', '167.089.523-86', 'maria_577@dominio.com'),
#  ('1847', 'Danilo Araújo', '562.148.709-58', 'danilo_939@dominio.com'),
#  ('1848', 'Maysa Rocha', '643.120.579-07', 'maysa_431@dominio.com'),
#  ('1849', 'Beatriz Rocha', '347.681.592-73', 'beatriz_504@dominio.com'),
#  ('185', 'João Santos', '278.096.435-92', 'joão_117@dominio.com'),
#  ('1850', 'Kaique Lima', '793.465.820-65', 'kaique_689@dominio.com'),
#  ('1851', 'Marina Moreira', '219.854.637-09', 'marina_216@dominio.com'),
#  ('1852', 'Maria Sophia da Rocha', '674.081.592-58', 'maria_606@dominio.com'),
#  ('1853', 'Diego Ramos', '162.093.874-03', 'diego_251@dominio.com'),
#  ('1854', 'Enzo Gabriel Freitas', '365.810.927-03', 'enzo_554@dominio.com'),
#  ('1855', 'Laura Rezende', '471.569.280-58', 'laura_171@dominio.com'),
#  ('1856', 'Pedro Miguel Porto', '507.246.913-16', 'pedro_223@dominio.com'),
#  ('1857', 'Vicente Martins', '124.685.037-08', 'vicente_695@dominio.com'),
#  ('1858', 'Gabrielly Pires', '126.543.907-99', 'gabrielly_345@dominio.com'),
#  ('1859', 'Davi Lucca Moura', '085.276.143-08', 'davi_757@dominio.com'),
#  ('186', 'Srta. Sarah Nascimento', '450.826.931-15', 'srta._990@dominio.com'),
#  ('1860', 'Lívia Pereira', '432.695.107-99', 'lívia_519@dominio.com'),
#  ('1861', 'Isabella da Mota', '134.290.687-03', 'isabella_504@dominio.com'),
#  ('1862', 'Yuri Correia', '291.364.750-25', 'yuri_329@dominio.com'),
#  ('1863', 'Anthony da Conceição', '348.169.570-57', 'anthony_628@dominio.com'),
#  ('1864', 'Mariane Cardoso', '547.013.286-26', 'mariane_645@dominio.com'),
#  ('1865', 'Vicente Azevedo', '260.791.834-04', 'vicente_519@dominio.com'),
#  ('1866', 'Sr. Renan Costela', '790.681.435-57', 'sr._961@dominio.com'),
#  ('1867', 'Yago Sales', '835.492.106-98', 'yago_922@dominio.com'),
#  ('1868', 'Thales Costa', '134.275.980-04', 'thales_714@dominio.com'),
#  ('1869', 'Sr. Samuel da Mata', '268.047.315-90', 'sr._321@dominio.com'),
#  ('187', 'Lucas Gabriel Farias', '815.372.409-60', 'lucas_905@dominio.com'),
#  ('1870', 'Francisco Almeida', '349.018.652-42', 'francisco_971@dominio.com'),
#  ('1871', 'Alice Melo', '815.320.467-07', 'alice_348@dominio.com'),
#  ('1872', 'Sr. Noah Gomes', '254.160.378-90', 'sr._882@dominio.com'),
#  ('1873', 'Nicole Silva', '816.973.054-66', 'nicole_278@dominio.com'),
#  ('1874', 'Henrique Ribeiro', '689.513.704-10', 'henrique_162@dominio.com'),
#  ('1875', 'Dra. Heloísa Caldeira', '894.265.031-70', 'dra._502@dominio.com'),
#  ('1876', 'Caio Cavalcanti', '142.653.870-71', 'caio_804@dominio.com'),
#  ('1877', 'Dr. Miguel da Cunha', '480.397.152-88', 'dr._931@dominio.com'),
#  ('1878', 'Luna Viana', '651.429.803-60', 'luna_623@dominio.com'),
#  ('1879', 'Maysa Gomes', '651.973.824-73', 'maysa_956@dominio.com'),
#  ('188', 'Maria Sophia Silveira', '789.160.435-57', 'maria_533@dominio.com'),
#  ('1880', 'Luigi Lopes', '568.410.932-24', 'luigi_375@dominio.com'),
#  ('1881', 'Kamilly Caldeira', '186.257.394-82', 'kamilly_657@dominio.com'),
#  ('1882', 'Maria Sophia Mendes', '431.697.058-57', 'maria_432@dominio.com'),
#  ('1883', 'Rebeca Novaes', '605.234.987-56', 'rebeca_982@dominio.com'),
#  ('1884', 'Joana Duarte', '682.539.014-70', 'joana_955@dominio.com'),
#  ('1885', 'Helena Pereira', '327.601.849-78', 'helena_367@dominio.com'),
#  ('1886', 'Sr. Antônio Barbosa', '896.570.132-59', 'sr._721@dominio.com'),
#  ('1887',
#   'Dr. João Lucas Nascimento',
#   '270.931.846-69',
#   'dr._502@dominio.com'),
#  ('1888', 'Milena Fogaça', '973.801.542-14', 'milena_570@dominio.com'),
#  ('1889', 'Vitória Novaes', '107.368.492-03', 'vitória_663@dominio.com'),
#  ('189', 'Daniela Moura', '256.398.074-74', 'daniela_231@dominio.com'),
#  ('1890', 'João Gabriel Moreira', '298.374.106-04', 'joão_320@dominio.com'),
#  ('1891', 'Juliana Dias', '845.671.239-64', 'juliana_854@dominio.com'),
#  ('1892', 'Elisa Fogaça', '073.216.854-62', 'elisa_917@dominio.com'),
#  ('1893', 'Alexia Pereira', '651.234.798-64', 'alexia_310@dominio.com'),
#  ('1894',
#   'Marcos Vinicius Gonçalves',
#   '102.463.587-26',
#   'marcos_160@dominio.com'),
#  ('1895', 'Dr. Gustavo Correia', '197.280.463-40', 'dr._936@dominio.com'),
#  ('1896', 'Valentina Costela', '897.126.305-95', 'valentina_544@dominio.com'),
#  ('1897', 'Maria Julia Teixeira', '416.583.027-53', 'maria_236@dominio.com'),
#  ('1898', 'Bernardo Novaes', '048.569.132-98', 'bernardo_510@dominio.com'),
#  ...]

# %%
query = f"""
DROP PROCEDURE IF EXISTS get_table;

CREATE PROCEDURE get_table(IN table_name VARCHAR(255))
BEGIN
    SET @sql = CONCAT('SELECT * FROM ', table_name);
    PREPARE stmt FROM @sql;
    EXECUTE stmt;
    DEALLOCATE PREPARE stmt;
END
"""

result = execute_query(query)
# Out:
# Executing query:
# DROP PROCEDURE IF EXISTS get_table;
#
# CREATE PROCEDURE get_table(IN table_name VARCHAR(255))
# BEGIN
#     SET @sql = CONCAT('SELECT * FROM ', table_name);
#     PREPARE stmt FROM @sql;
#     EXECUTE stmt;
#     DEALLOCATE PREPARE stmt;
# END
#  with params: None

# %%
query = f"""
CALL get_table('avaliacoes')
"""

result = execute_query(query)
result
# Out:
# Executing query:
# CALL get_table('avaliacoes')
#  with params: None
#
#
# Query returned 9999 rows.
# [('1', '1', '8450', 2, 'Horrível localização.'),
#  ('10', '10', '198', 2, 'Horrível atendimento.'),
#  ('100', '100', '4019', 2, 'Péssima infraestrutura.'),
#  ('1000', '1000', '5108', 3, 'Maravilhosa serviços.'),
#  ('10000', '10000', '8802', 3, 'Excelente limpeza.'),
#  ('1001', '1001', '3397', 4, 'Ótima atendimento.'),
#  ('1002', '1002', '8131', 1, 'Desconfortável limpeza.'),
#  ('1003', '1003', '5657', 3, 'Agradável serviços.'),
#  ('1004', '1004', '4261', 4, 'Excelente atendimento.'),
#  ('1005', '1005', '3210', 5, 'Incrível localização.'),
#  ('1006', '1006', '9366', 1, 'Péssima serviços.'),
#  ('1007', '1007', '155', 3, 'Incrível serviços.'),
#  ('1008', '1008', '4246', 4, 'Maravilhosa localização.'),
#  ('1009', '1009', '5233', 5, 'Ótima limpeza.'),
#  ('101', '101', '8635', 3, 'Ótima limpeza.'),
#  ('1010', '1010', '8621', 2, 'Desagradável limpeza.'),
#  ('1011', '1011', '6541', 4, 'Confortável infraestrutura.'),
#  ('1012', '1012', '2050', 4, 'Agradável infraestrutura.'),
#  ('1013', '1013', '2515', 4, 'Ótima localização.'),
#  ('1014', '1014', '9400', 4, 'Maravilhosa infraestrutura.'),
#  ('1015', '1015', '1520', 5, 'Incrível serviços.'),
#  ('1016', '1016', '5935', 3, 'Incrível serviços.'),
#  ('1017', '1017', '8496', 2, 'Péssima localização.'),
#  ('1018', '1018', '2503', 3, 'Excelente infraestrutura.'),
#  ('1019', '1019', '4546', 2, 'Terrível serviços.'),
#  ('102', '102', '2514', 1, 'Péssima limpeza.'),
#  ('1020', '1020', '6831', 1, 'Desagradável localização.'),
#  ('1021', '1021', '3932', 1, 'Desconfortável limpeza.'),
#  ('1022', '1022', '4357', 1, 'Horrível infraestrutura.'),
#  ('1023', '1023', '9456', 4, 'Maravilhosa serviços.'),
#  ('1024', '1024', '3537', 1, 'Terrível atendimento.'),
#  ('1025', '1025', '6777', 2, 'Péssima atendimento.'),
#  ('1026', '1026', '6197', 5, 'Maravilhosa serviços.'),
#  ('1027', '1027', '958', 1, 'Horrível infraestrutura.'),
#  ('1028', '1028', '2173', 2, 'Ruim limpeza.'),
#  ('1029', '1029', '1677', 2, 'Terrível limpeza.'),
#  ('103', '103', '3566', 5, 'Maravilhosa serviços.'),
#  ('1030', '1030', '19', 5, 'Excelente infraestrutura.'),
#  ('1031', '1031', '9222', 3, 'Agradável atendimento.'),
#  ('1032', '1032', '1450', 2, 'Ruim serviços.'),
#  ('1033', '1033', '2086', 3, 'Excelente localização.'),
#  ('1034', '1034', '8388', 3, 'Excelente serviços.'),
#  ('1035', '1035', '9716', 2, 'Horrível localização.'),
#  ('1036', '1036', '9631', 3, 'Ótima limpeza.'),
#  ('1037', '1037', '3178', 4, 'Ótima serviços.'),
#  ('1038', '1038', '5027', 2, 'Desagradável atendimento.'),
#  ('1039', '1039', '9633', 5, 'Ótima atendimento.'),
#  ('104', '104', '51', 1, 'Terrível limpeza.'),
#  ('1040', '1040', '1163', 1, 'Terrível atendimento.'),
#  ('1041', '1041', '9719', 3, 'Ótima atendimento.'),
#  ('1042', '1042', '2588', 4, 'Confortável serviços.'),
#  ('1043', '1043', '1613', 3, 'Excelente infraestrutura.'),
#  ('1044', '1044', '3357', 1, 'Péssima localização.'),
#  ('1045', '1045', '935', 1, 'Desagradável localização.'),
#  ('1046', '1046', '3551', 3, 'Excelente atendimento.'),
#  ('1047', '1047', '6642', 5, 'Agradável infraestrutura.'),
#  ('1048', '1048', '9442', 2, 'Terrível limpeza.'),
#  ('1049', '1049', '566', 1, 'Desagradável limpeza.'),
#  ('105', '105', '9486', 1, 'Desagradável limpeza.'),
#  ('1050', '1050', '7470', 1, 'Terrível serviços.'),
#  ('1051', '1051', '7740', 2, 'Péssima limpeza.'),
#  ('1052', '1052', '6406', 2, 'Terrível infraestrutura.'),
#  ('1053', '1053', '6636', 5, 'Excelente localização.'),
#  ('1054', '1054', '5228', 1, 'Desconfortável limpeza.'),
#  ('1055', '1055', '1401', 2, 'Terrível infraestrutura.'),
#  ('1056', '1056', '5971', 4, 'Agradável limpeza.'),
#  ('1057', '1057', '8362', 4, 'Ótima localização.'),
#  ('1058', '1058', '4041', 2, 'Péssima infraestrutura.'),
#  ('1059', '1059', '1902', 1, 'Desconfortável serviços.'),
#  ('106', '106', '6298', 3, 'Excelente serviços.'),
#  ('1060', '1060', '597', 1, 'Desagradável infraestrutura.'),
#  ('1061', '1061', '2011', 2, 'Horrível localização.'),
#  ('1062', '1062', '7142', 5, 'Excelente atendimento.'),
#  ('1063', '1063', '177', 2, 'Terrível infraestrutura.'),
#  ('1064', '1064', '8399', 1, 'Desagradável localização.'),
#  ('1065', '1065', '3024', 5, 'Incrível limpeza.'),
#  ('1066', '1066', '643', 3, 'Confortável localização.'),
#  ('1067', '1067', '9504', 5, 'Incrível limpeza.'),
#  ('1068', '1068', '6819', 4, 'Excelente localização.'),
#  ('1069', '1069', '8133', 2, 'Terrível atendimento.'),
#  ('107', '107', '7362', 4, 'Incrível infraestrutura.'),
#  ('1070', '1070', '4171', 2, 'Horrível limpeza.'),
#  ('1071', '1071', '6136', 2, 'Desagradável localização.'),
#  ('1072', '1072', '406', 2, 'Péssima localização.'),
#  ('1073', '1073', '9401', 1, 'Desconfortável infraestrutura.'),
#  ('1074', '1074', '4421', 1, 'Desconfortável serviços.'),
#  ('1075', '1075', '2778', 4, 'Ótima atendimento.'),
#  ('1076', '1076', '9778', 5, 'Agradável serviços.'),
#  ('1077', '1077', '6699', 4, 'Excelente limpeza.'),
#  ('1078', '1078', '1111', 4, 'Ótima infraestrutura.'),
#  ('1079', '1079', '5857', 4, 'Confortável localização.'),
#  ('108', '108', '4631', 5, 'Ótima atendimento.'),
#  ('1080', '1080', '343', 1, 'Desagradável localização.'),
#  ('1081', '1081', '9090', 2, 'Terrível atendimento.'),
#  ('1082', '1082', '9069', 1, 'Horrível atendimento.'),
#  ('1083', '1083', '6831', 2, 'Terrível limpeza.'),
#  ('1084', '1084', '2871', 2, 'Ruim atendimento.'),
#  ('1085', '1085', '9647', 5, 'Ótima limpeza.'),
#  ('1086', '1086', '9606', 3, 'Maravilhosa localização.'),
#  ('1087', '1087', '285', 3, 'Incrível limpeza.'),
#  ('1088', '1088', '4450', 5, 'Ótima serviços.'),
#  ('1089', '1089', '9524', 1, 'Horrível infraestrutura.'),
#  ('109', '109', '6515', 3, 'Confortável serviços.'),
#  ('1090', '1090', '4502', 3, 'Excelente atendimento.'),
#  ('1091', '1091', '7512', 4, 'Ótima localização.'),
#  ('1092', '1092', '3126', 5, 'Maravilhosa atendimento.'),
#  ('1093', '1093', '9812', 5, 'Maravilhosa infraestrutura.'),
#  ('1094', '1094', '6996', 2, 'Horrível infraestrutura.'),
#  ('1095', '1095', '4815', 4, 'Agradável infraestrutura.'),
#  ('1096', '1096', '8247', 1, 'Ruim limpeza.'),
#  ('1097', '1097', '6004', 1, 'Péssima localização.'),
#  ('1098', '1098', '1519', 5, 'Agradável localização.'),
#  ('1099', '1099', '1537', 3, 'Maravilhosa localização.'),
#  ('11', '11', '3173', 2, 'Horrível localização.'),
#  ('110', '110', '154', 3, 'Agradável limpeza.'),
#  ('1100', '1100', '710', 5, 'Maravilhosa serviços.'),
#  ('1101', '1101', '9248', 1, 'Desagradável localização.'),
#  ('1102', '1102', '3079', 5, 'Confortável infraestrutura.'),
#  ('1103', '1103', '9373', 3, 'Maravilhosa serviços.'),
#  ('1104', '1104', '5207', 1, 'Péssima limpeza.'),
#  ('1105', '1105', '8302', 1, 'Desagradável serviços.'),
#  ('1106', '1106', '6057', 4, 'Maravilhosa atendimento.'),
#  ('1107', '1107', '7956', 2, 'Desconfortável localização.'),
#  ('1108', '1108', '4467', 4, 'Agradável localização.'),
#  ('1109', '1109', '5390', 1, 'Horrível infraestrutura.'),
#  ('111', '111', '6911', 4, 'Confortável localização.'),
#  ('1110', '1110', '4068', 2, 'Desagradável infraestrutura.'),
#  ('1111', '1111', '3927', 2, 'Desagradável localização.'),
#  ('1112', '1112', '2792', 2, 'Desagradável localização.'),
#  ('1113', '1113', '3730', 3, 'Ótima limpeza.'),
#  ('1114', '1114', '3001', 5, 'Agradável limpeza.'),
#  ('1115', '1115', '7437', 4, 'Excelente serviços.'),
#  ('1116', '1116', '1382', 4, 'Excelente localização.'),
#  ('1117', '1117', '493', 4, 'Agradável limpeza.'),
#  ('1118', '1118', '3845', 2, 'Ruim infraestrutura.'),
#  ('1119', '1119', '6245', 5, 'Confortável limpeza.'),
#  ('112', '112', '6137', 2, 'Ruim atendimento.'),
#  ('1120', '1120', '5519', 3, 'Agradável serviços.'),
#  ('1121', '1121', '6645', 3, 'Maravilhosa localização.'),
#  ('1122', '1122', '7433', 2, 'Desagradável atendimento.'),
#  ('1123', '1123', '7078', 1, 'Desagradável localização.'),
#  ('1124', '1124', '2720', 3, 'Excelente atendimento.'),
#  ('1125', '1125', '4189', 4, 'Incrível atendimento.'),
#  ('1126', '1126', '1533', 2, 'Ruim limpeza.'),
#  ('1127', '1127', '8382', 5, 'Maravilhosa atendimento.'),
#  ('1128', '1128', '2956', 1, 'Ruim localização.'),
#  ('1129', '1129', '1688', 2, 'Ruim infraestrutura.'),
#  ('113', '113', '5779', 4, 'Maravilhosa atendimento.'),
#  ('1130', '1130', '8305', 3, 'Excelente atendimento.'),
#  ('1131', '1131', '5194', 2, 'Terrível infraestrutura.'),
#  ('1132', '1132', '5246', 2, 'Ruim atendimento.'),
#  ('1133', '1133', '3937', 3, 'Incrível serviços.'),
#  ('1134', '1134', '7087', 2, 'Desconfortável limpeza.'),
#  ('1135', '1135', '8308', 1, 'Terrível localização.'),
#  ('1136', '1136', '1901', 5, 'Ótima serviços.'),
#  ('1137', '1137', '7895', 4, 'Incrível infraestrutura.'),
#  ('1138', '1138', '3395', 5, 'Confortável serviços.'),
#  ('1139', '1139', '5827', 1, 'Ruim serviços.'),
#  ('114', '114', '28', 2, 'Terrível serviços.'),
#  ('1140', '1140', '2542', 2, 'Péssima serviços.'),
#  ('1141', '1141', '2326', 5, 'Excelente serviços.'),
#  ('1142', '1142', '8479', 4, 'Agradável infraestrutura.'),
#  ('1143', '1143', '9549', 1, 'Desconfortável limpeza.'),
#  ('1144', '1144', '2108', 1, 'Desconfortável serviços.'),
#  ('1145', '1145', '6614', 4, 'Maravilhosa localização.'),
#  ('1146', '1146', '2040', 1, 'Horrível limpeza.'),
#  ('1147', '1147', '9101', 4, 'Ótima infraestrutura.'),
#  ('1148', '1148', '6916', 3, 'Agradável atendimento.'),
#  ('1149', '1149', '5633', 2, 'Desconfortável limpeza.'),
#  ('115', '115', '2433', 3, 'Ótima serviços.'),
#  ('1150', '1150', '444', 5, 'Ótima localização.'),
#  ('1151', '1151', '5986', 3, 'Agradável serviços.'),
#  ('1152', '1152', '2413', 4, 'Ótima infraestrutura.'),
#  ('1153', '1153', '8475', 5, 'Ótima localização.'),
#  ('1154', '1154', '7007', 5, 'Maravilhosa localização.'),
#  ('1155', '1155', '8927', 2, 'Desagradável limpeza.'),
#  ('1156', '1156', '3045', 3, 'Confortável infraestrutura.'),
#  ('1157', '1157', '7372', 5, 'Confortável limpeza.'),
#  ('1158', '1158', '6937', 1, 'Péssima localização.'),
#  ('1159', '1159', '2701', 1, 'Desagradável limpeza.'),
#  ('116', '116', '1345', 1, 'Desconfortável serviços.'),
#  ('1160', '1160', '9521', 3, 'Incrível atendimento.'),
#  ('1161', '1161', '6135', 2, 'Horrível serviços.'),
#  ('1162', '1162', '666', 2, 'Desconfortável atendimento.'),
#  ('1163', '1163', '2532', 3, 'Confortável localização.'),
#  ('1164', '1164', '683', 1, 'Terrível infraestrutura.'),
#  ('1165', '1165', '2340', 2, 'Desagradável localização.'),
#  ('1166', '1166', '1101', 3, 'Ótima infraestrutura.'),
#  ('1167', '1167', '220', 5, 'Incrível serviços.'),
#  ('1168', '1168', '3098', 5, 'Agradável atendimento.'),
#  ('1169', '1169', '5608', 4, 'Excelente atendimento.'),
#  ('117', '117', '143', 2, 'Horrível serviços.'),
#  ('1170', '1170', '383', 1, 'Desconfortável localização.'),
#  ('1171', '1171', '3350', 2, 'Desagradável atendimento.'),
#  ('1172', '1172', '6979', 3, 'Ótima atendimento.'),
#  ('1173', '1173', '8057', 5, 'Maravilhosa atendimento.'),
#  ('1174', '1174', '96', 4, 'Excelente localização.'),
#  ('1175', '1175', '4915', 1, 'Desagradável limpeza.'),
#  ('1176', '1176', '3275', 5, 'Maravilhosa infraestrutura.'),
#  ('1177', '1177', '2837', 5, 'Agradável infraestrutura.'),
#  ('1178', '1178', '2614', 4, 'Ótima localização.'),
#  ('1179', '1179', '8412', 1, 'Desconfortável serviços.'),
#  ('118', '118', '1244', 5, 'Excelente limpeza.'),
#  ('1180', '1180', '881', 4, 'Agradável limpeza.'),
#  ('1181', '1181', '8010', 2, 'Desconfortável localização.'),
#  ('1182', '1182', '2177', 2, 'Desconfortável limpeza.'),
#  ('1183', '1183', '312', 5, 'Excelente infraestrutura.'),
#  ('1184', '1184', '711', 2, 'Péssima limpeza.'),
#  ('1185', '1185', '9514', 3, 'Excelente localização.'),
#  ('1186', '1186', '6346', 2, 'Horrível infraestrutura.'),
#  ('1187', '1187', '6275', 4, 'Confortável serviços.'),
#  ('1188', '1188', '2759', 1, 'Desconfortável serviços.'),
#  ('1189', '1189', '1580', 4, 'Incrível atendimento.'),
#  ('119', '119', '7669', 4, 'Maravilhosa atendimento.'),
#  ('1190', '1190', '4896', 1, 'Terrível atendimento.'),
#  ('1191', '1191', '7612', 1, 'Ruim serviços.'),
#  ('1192', '1192', '9555', 1, 'Terrível atendimento.'),
#  ('1193', '1193', '1829', 4, 'Ótima limpeza.'),
#  ('1194', '1194', '3', 2, 'Ruim serviços.'),
#  ('1195', '1195', '3195', 5, 'Ótima infraestrutura.'),
#  ('1196', '1196', '4318', 4, 'Maravilhosa infraestrutura.'),
#  ('1197', '1197', '9426', 5, 'Ótima infraestrutura.'),
#  ('1198', '1198', '2868', 1, 'Desagradável serviços.'),
#  ('1199', '1199', '6422', 2, 'Terrível serviços.'),
#  ('12', '12', '5112', 4, 'Ótima atendimento.'),
#  ('120', '120', '1281', 3, 'Maravilhosa serviços.'),
#  ('1200', '1200', '2585', 3, 'Incrível limpeza.'),
#  ('1201', '1201', '1887', 5, 'Excelente serviços.'),
#  ('1202', '1202', '1153', 2, 'Horrível localização.'),
#  ('1203', '1203', '4634', 2, 'Terrível limpeza.'),
#  ('1204', '1204', '9125', 4, 'Excelente limpeza.'),
#  ('1205', '1205', '2585', 3, 'Incrível atendimento.'),
#  ('1206', '1206', '9884', 2, 'Péssima serviços.'),
#  ('1207', '1207', '4959', 2, 'Desconfortável infraestrutura.'),
#  ('1208', '1208', '4181', 2, 'Horrível localização.'),
#  ('1209', '1209', '9298', 2, 'Terrível serviços.'),
#  ('121', '121', '1914', 5, 'Maravilhosa atendimento.'),
#  ('1210', '1210', '9446', 4, 'Incrível serviços.'),
#  ('1211', '1211', '4830', 5, 'Incrível infraestrutura.'),
#  ('1212', '1212', '6667', 2, 'Desagradável limpeza.'),
#  ('1213', '1213', '9251', 2, 'Horrível serviços.'),
#  ('1214', '1214', '1112', 4, 'Excelente atendimento.'),
#  ('1215', '1215', '6000', 5, 'Maravilhosa atendimento.'),
#  ('1216', '1216', '4008', 5, 'Excelente localização.'),
#  ('1217', '1217', '9930', 1, 'Desconfortável serviços.'),
#  ('1218', '1218', '2456', 2, 'Desconfortável infraestrutura.'),
#  ('1219', '1219', '9771', 5, 'Maravilhosa infraestrutura.'),
#  ('122', '122', '9398', 5, 'Incrível localização.'),
#  ('1220', '1220', '9776', 2, 'Terrível localização.'),
#  ('1221', '1221', '2558', 4, 'Incrível serviços.'),
#  ('1222', '1222', '8703', 1, 'Desconfortável atendimento.'),
#  ('1223', '1223', '4030', 5, 'Confortável infraestrutura.'),
#  ('1224', '1224', '1663', 3, 'Excelente limpeza.'),
#  ('1225', '1225', '5700', 3, 'Agradável limpeza.'),
#  ('1226', '1226', '9889', 2, 'Ruim serviços.'),
#  ('1227', '1227', '2125', 5, 'Maravilhosa limpeza.'),
#  ('1228', '1228', '4191', 3, 'Ótima localização.'),
#  ('1229', '1229', '5808', 2, 'Péssima limpeza.'),
#  ('123', '123', '3500', 3, 'Excelente limpeza.'),
#  ('1230', '1230', '3312', 2, 'Péssima atendimento.'),
#  ('1231', '1231', '6382', 1, 'Péssima serviços.'),
#  ('1232', '1232', '9304', 4, 'Confortável localização.'),
#  ('1233', '1233', '1122', 4, 'Excelente infraestrutura.'),
#  ('1234', '1234', '2031', 1, 'Ruim atendimento.'),
#  ('1235', '1235', '4925', 5, 'Incrível localização.'),
#  ('1236', '1236', '332', 2, 'Horrível localização.'),
#  ('1237', '1237', '4630', 2, 'Péssima localização.'),
#  ('1238', '1238', '4960', 1, 'Desconfortável infraestrutura.'),
#  ('1239', '1239', '3250', 2, 'Desconfortável infraestrutura.'),
#  ('124', '124', '9070', 5, 'Confortável infraestrutura.'),
#  ('1240', '1240', '2930', 3, 'Excelente localização.'),
#  ('1241', '1241', '5589', 2, 'Desagradável atendimento.'),
#  ('1242', '1242', '6078', 5, 'Maravilhosa atendimento.'),
#  ('1243', '1243', '2573', 3, 'Incrível limpeza.'),
#  ('1244', '1244', '4005', 5, 'Confortável localização.'),
#  ('1245', '1245', '3080', 3, 'Excelente atendimento.'),
#  ('1246', '1246', '2108', 1, 'Péssima localização.'),
#  ('1247', '1247', '6377', 4, 'Excelente localização.'),
#  ('1248', '1248', '5295', 5, 'Incrível atendimento.'),
#  ('1249', '1249', '3773', 3, 'Confortável serviços.'),
#  ('125', '125', '1820', 2, 'Terrível limpeza.'),
#  ('1250', '1250', '2394', 4, 'Agradável limpeza.'),
#  ('1251', '1251', '8835', 4, 'Agradável infraestrutura.'),
#  ('1252', '1252', '3500', 4, 'Maravilhosa infraestrutura.'),
#  ('1253', '1253', '655', 4, 'Agradável serviços.'),
#  ('1254', '1254', '1709', 3, 'Confortável infraestrutura.'),
#  ('1255', '1255', '6320', 2, 'Desconfortável serviços.'),
#  ('1256', '1256', '8780', 5, 'Maravilhosa limpeza.'),
#  ('1257', '1257', '1512', 3, 'Excelente limpeza.'),
#  ('1258', '1258', '7252', 2, 'Péssima atendimento.'),
#  ('1259', '1259', '1546', 5, 'Confortável atendimento.'),
#  ('126', '126', '4909', 5, 'Agradável atendimento.'),
#  ('1260', '1260', '4635', 5, 'Ótima serviços.'),
#  ('1261', '1261', '8793', 4, 'Incrível atendimento.'),
#  ('1262', '1262', '9226', 5, 'Excelente localização.'),
#  ('1263', '1263', '2449', 3, 'Ótima localização.'),
#  ('1264', '1264', '9930', 5, 'Agradável limpeza.'),
#  ('1265', '1265', '8170', 1, 'Ruim localização.'),
#  ('1266', '1266', '3672', 5, 'Agradável localização.'),
#  ('1267', '1267', '3122', 1, 'Ruim serviços.'),
#  ('1268', '1268', '8526', 2, 'Péssima atendimento.'),
#  ('1269', '1269', '8145', 5, 'Maravilhosa serviços.'),
#  ('127', '127', '1706', 1, 'Desconfortável serviços.'),
#  ('1270', '1270', '3629', 3, 'Agradável localização.'),
#  ('1271', '1271', '6749', 2, 'Terrível atendimento.'),
#  ('1272', '1272', '3679', 5, 'Incrível limpeza.'),
#  ('1273', '1273', '2664', 4, 'Incrível infraestrutura.'),
#  ('1274', '1274', '952', 4, 'Ótima atendimento.'),
#  ('1275', '1275', '186', 2, 'Ruim serviços.'),
#  ('1276', '1276', '4651', 4, 'Ótima serviços.'),
#  ('1277', '1277', '8869', 2, 'Desconfortável atendimento.'),
#  ('1278', '1278', '1230', 5, 'Maravilhosa limpeza.'),
#  ('1279', '1279', '4102', 3, 'Maravilhosa localização.'),
#  ('128', '128', '4642', 3, 'Incrível atendimento.'),
#  ('1280', '1280', '1823', 5, 'Ótima limpeza.'),
#  ('1281', '1281', '572', 2, 'Desagradável limpeza.'),
#  ('1282', '1282', '2096', 3, 'Confortável infraestrutura.'),
#  ('1283', '1283', '4436', 4, 'Incrível serviços.'),
#  ('1284', '1284', '6125', 4, 'Agradável limpeza.'),
#  ('1285', '1285', '4312', 5, 'Confortável limpeza.'),
#  ('1286', '1286', '6446', 4, 'Incrível localização.'),
#  ('1287', '1287', '1660', 4, 'Confortável localização.'),
#  ('1288', '1288', '3601', 2, 'Desconfortável limpeza.'),
#  ('1289', '1289', '7546', 4, 'Confortável atendimento.'),
#  ('129', '129', '1531', 5, 'Agradável infraestrutura.'),
#  ('1290', '1290', '5966', 2, 'Desagradável infraestrutura.'),
#  ('1291', '1291', '1580', 3, 'Excelente infraestrutura.'),
#  ('1292', '1292', '4208', 5, 'Agradável serviços.'),
#  ('1293', '1293', '1383', 4, 'Excelente atendimento.'),
#  ('1294', '1294', '9154', 5, 'Incrível infraestrutura.'),
#  ('1295', '1295', '7632', 2, 'Desconfortável limpeza.'),
#  ('1296', '1296', '4696', 5, 'Excelente atendimento.'),
#  ('1297', '1297', '946', 1, 'Horrível infraestrutura.'),
#  ('1298', '1298', '9732', 4, 'Incrível serviços.'),
#  ('1299', '1299', '5672', 3, 'Confortável serviços.'),
#  ('13', '13', '4687', 5, 'Confortável limpeza.'),
#  ('130', '130', '9110', 2, 'Desagradável serviços.'),
#  ('1300', '1300', '1645', 2, 'Ruim serviços.'),
#  ('1301', '1301', '4331', 2, 'Desconfortável limpeza.'),
#  ('1302', '1302', '6027', 3, 'Agradável localização.'),
#  ('1303', '1303', '4082', 5, 'Confortável atendimento.'),
#  ('1304', '1304', '6334', 3, 'Ótima serviços.'),
#  ('1305', '1305', '2362', 3, 'Agradável limpeza.'),
#  ('1306', '1306', '6405', 5, 'Maravilhosa infraestrutura.'),
#  ('1307', '1307', '2997', 2, 'Desconfortável serviços.'),
#  ('1308', '1308', '4472', 3, 'Agradável localização.'),
#  ('1309', '1309', '9078', 5, 'Excelente serviços.'),
#  ('131', '131', '148', 1, 'Horrível serviços.'),
#  ('1310', '1310', '9680', 5, 'Incrível serviços.'),
#  ('1311', '1311', '2300', 2, 'Horrível atendimento.'),
#  ('1312', '1312', '6922', 5, 'Ótima limpeza.'),
#  ('1313', '1313', '1978', 1, 'Desconfortável serviços.'),
#  ('1314', '1314', '8642', 5, 'Confortável atendimento.'),
#  ('1315', '1315', '3974', 3, 'Agradável serviços.'),
#  ('1316', '1316', '2595', 2, 'Desagradável atendimento.'),
#  ('1317', '1317', '6968', 1, 'Péssima atendimento.'),
#  ('1318', '1318', '7474', 1, 'Horrível infraestrutura.'),
#  ('1319', '1319', '8076', 1, 'Terrível infraestrutura.'),
#  ('132', '132', '4572', 1, 'Péssima localização.'),
#  ('1320', '1320', '8322', 4, 'Incrível serviços.'),
#  ('1321', '1321', '5574', 4, 'Incrível limpeza.'),
#  ('1322', '1322', '5873', 3, 'Excelente serviços.'),
#  ('1323', '1323', '5819', 2, 'Ruim infraestrutura.'),
#  ('1324', '1324', '6029', 4, 'Maravilhosa limpeza.'),
#  ('1325', '1325', '8557', 1, 'Terrível atendimento.'),
#  ('1326', '1326', '2814', 2, 'Péssima atendimento.'),
#  ('1327', '1327', '7291', 1, 'Desconfortável infraestrutura.'),
#  ('1328', '1328', '230', 5, 'Maravilhosa localização.'),
#  ('1329', '1329', '311', 3, 'Excelente limpeza.'),
#  ('133', '133', '6473', 5, 'Maravilhosa limpeza.'),
#  ('1330', '1330', '7058', 4, 'Excelente infraestrutura.'),
#  ('1331', '1331', '1904', 3, 'Excelente localização.'),
#  ('1332', '1332', '1961', 5, 'Excelente infraestrutura.'),
#  ('1333', '1333', '3808', 4, 'Ótima localização.'),
#  ('1334', '1334', '2802', 2, 'Ruim atendimento.'),
#  ('1335', '1335', '715', 3, 'Confortável limpeza.'),
#  ('1336', '1336', '1459', 2, 'Terrível limpeza.'),
#  ('1337', '1337', '436', 5, 'Maravilhosa limpeza.'),
#  ('1338', '1338', '5022', 4, 'Ótima limpeza.'),
#  ('1339', '1339', '5513', 5, 'Agradável serviços.'),
#  ('134', '134', '7941', 2, 'Ruim localização.'),
#  ('1340', '1340', '3081', 1, 'Terrível serviços.'),
#  ('1341', '1341', '5718', 2, 'Terrível atendimento.'),
#  ('1342', '1342', '2551', 1, 'Desconfortável serviços.'),
#  ('1343', '1343', '7939', 3, 'Excelente localização.'),
#  ('1344', '1344', '4894', 5, 'Ótima atendimento.'),
#  ('1345', '1345', '1639', 3, 'Agradável atendimento.'),
#  ('1346', '1346', '8693', 1, 'Desagradável serviços.'),
#  ('1347', '1347', '5592', 4, 'Confortável limpeza.'),
#  ('1348', '1348', '6399', 5, 'Maravilhosa atendimento.'),
#  ('1349', '1349', '6288', 1, 'Desagradável localização.'),
#  ('135', '135', '9123', 5, 'Incrível infraestrutura.'),
#  ('1350', '1350', '2233', 3, 'Agradável serviços.'),
#  ('1351', '1351', '991', 5, 'Agradável localização.'),
#  ('1352', '1352', '475', 2, 'Ruim atendimento.'),
#  ('1353', '1353', '1633', 2, 'Ruim localização.'),
#  ('1354', '1354', '3031', 3, 'Excelente atendimento.'),
#  ('1355', '1355', '9129', 3, 'Ótima atendimento.'),
#  ('1356', '1356', '2346', 3, 'Maravilhosa serviços.'),
#  ('1357', '1357', '939', 4, 'Ótima limpeza.'),
#  ('1358', '1358', '6136', 4, 'Excelente infraestrutura.'),
#  ('1359', '1359', '8548', 2, 'Terrível limpeza.'),
#  ('136', '136', '1071', 5, 'Confortável infraestrutura.'),
#  ('1360', '1360', '3415', 4, 'Ótima serviços.'),
#  ('1361', '1361', '9034', 2, 'Desagradável limpeza.'),
#  ('1362', '1362', '7494', 5, 'Ótima limpeza.'),
#  ('1363', '1363', '1782', 4, 'Agradável serviços.'),
#  ('1364', '1364', '4692', 2, 'Terrível atendimento.'),
#  ('1365', '1365', '3473', 5, 'Excelente infraestrutura.'),
#  ('1366', '1366', '9575', 2, 'Ruim limpeza.'),
#  ('1367', '1367', '8395', 4, 'Ótima serviços.'),
#  ('1368', '1368', '4428', 1, 'Desagradável serviços.'),
#  ('1369', '1369', '8130', 3, 'Confortável infraestrutura.'),
#  ('137', '137', '4384', 4, 'Maravilhosa localização.'),
#  ('1370', '1370', '6324', 2, 'Desconfortável infraestrutura.'),
#  ('1371', '1371', '4574', 3, 'Ótima localização.'),
#  ('1372', '1372', '1310', 2, 'Desconfortável limpeza.'),
#  ('1373', '1373', '782', 2, 'Péssima localização.'),
#  ('1374', '1374', '1047', 1, 'Ruim infraestrutura.'),
#  ('1375', '1375', '5723', 3, 'Maravilhosa serviços.'),
#  ('1376', '1376', '9977', 3, 'Maravilhosa atendimento.'),
#  ('1377', '1377', '7471', 3, 'Incrível limpeza.'),
#  ('1378', '1378', '2614', 4, 'Incrível localização.'),
#  ('1379', '1379', '8014', 5, 'Incrível atendimento.'),
#  ('138', '138', '3880', 3, 'Agradável localização.'),
#  ('1380', '1380', '6558', 2, 'Desconfortável atendimento.'),
#  ('1381', '1381', '9609', 1, 'Desconfortável infraestrutura.'),
#  ('1382', '1382', '6774', 5, 'Maravilhosa atendimento.'),
#  ('1383', '1383', '9648', 5, 'Ótima limpeza.'),
#  ('1384', '1384', '1960', 2, 'Desconfortável infraestrutura.'),
#  ('1385', '1385', '3647', 3, 'Incrível infraestrutura.'),
#  ('1386', '1386', '7590', 2, 'Péssima atendimento.'),
#  ('1387', '1387', '3652', 1, 'Péssima limpeza.'),
#  ('1388', '1388', '9568', 1, 'Terrível infraestrutura.'),
#  ('1389', '1389', '3939', 2, 'Péssima serviços.'),
#  ('139', '139', '8652', 5, 'Excelente localização.'),
#  ('1390', '1390', '789', 1, 'Ruim serviços.'),
#  ('1391', '1391', '2658', 4, 'Maravilhosa serviços.'),
#  ('1392', '1392', '2850', 3, 'Maravilhosa localização.'),
#  ('1393', '1393', '9620', 4, 'Incrível limpeza.'),
#  ('1394', '1394', '594', 4, 'Excelente atendimento.'),
#  ('1395', '1395', '1562', 1, 'Terrível infraestrutura.'),
#  ('1396', '1396', '3472', 3, 'Incrível atendimento.'),
#  ('1397', '1397', '9843', 1, 'Desagradável infraestrutura.'),
#  ('1398', '1398', '3531', 5, 'Incrível localização.'),
#  ('1399', '1399', '2301', 3, 'Confortável limpeza.'),
#  ('14', '14', '8411', 5, 'Confortável limpeza.'),
#  ('140', '140', '3687', 2, 'Horrível serviços.'),
#  ('1400', '1400', '1844', 1, 'Péssima localização.'),
#  ('1401', '1401', '440', 1, 'Desagradável localização.'),
#  ('1402', '1402', '2368', 3, 'Ótima atendimento.'),
#  ('1403', '1403', '9262', 1, 'Terrível serviços.'),
#  ('1404', '1404', '9565', 4, 'Agradável limpeza.'),
#  ('1405', '1405', '7105', 5, 'Maravilhosa localização.'),
#  ('1406', '1406', '4144', 4, 'Incrível infraestrutura.'),
#  ('1407', '1407', '4907', 4, 'Agradável infraestrutura.'),
#  ('1408', '1408', '8252', 2, 'Ruim limpeza.'),
#  ('1409', '1409', '7971', 4, 'Ótima limpeza.'),
#  ('141', '141', '9072', 2, 'Ruim atendimento.'),
#  ('1410', '1410', '3905', 3, 'Ótima serviços.'),
#  ('1411', '1411', '2793', 1, 'Péssima limpeza.'),
#  ('1412', '1412', '1928', 2, 'Ruim limpeza.'),
#  ('1413', '1413', '7138', 1, 'Desconfortável serviços.'),
#  ('1414', '1414', '6001', 1, 'Horrível serviços.'),
#  ('1415', '1415', '1918', 2, 'Ruim limpeza.'),
#  ('1416', '1416', '8296', 3, 'Maravilhosa serviços.'),
#  ('1417', '1417', '8893', 2, 'Desagradável infraestrutura.'),
#  ('1418', '1418', '2281', 5, 'Confortável infraestrutura.'),
#  ('1419', '1419', '4584', 2, 'Desagradável limpeza.'),
#  ('142', '142', '5983', 4, 'Confortável serviços.'),
#  ('1420', '1420', '6647', 4, 'Agradável atendimento.'),
#  ('1421', '1421', '7643', 1, 'Desagradável serviços.'),
#  ('1422', '1422', '7795', 2, 'Desconfortável infraestrutura.'),
#  ('1423', '1423', '2217', 4, 'Excelente infraestrutura.'),
#  ('1424', '1424', '9927', 2, 'Horrível atendimento.'),
#  ('1425', '1425', '942', 1, 'Desconfortável serviços.'),
#  ('1426', '1426', '9055', 1, 'Ruim localização.'),
#  ('1427', '1427', '2480', 1, 'Péssima infraestrutura.'),
#  ('1428', '1428', '6779', 4, 'Excelente atendimento.'),
#  ('1429', '1429', '3762', 3, 'Incrível serviços.'),
#  ('143', '143', '6465', 5, 'Agradável limpeza.'),
#  ('1430', '1430', '720', 2, 'Horrível limpeza.'),
#  ('1431', '1431', '3013', 2, 'Péssima serviços.'),
#  ('1432', '1432', '2763', 3, 'Ótima localização.'),
#  ('1433', '1433', '6834', 2, 'Péssima localização.'),
#  ('1434', '1434', '7186', 5, 'Excelente atendimento.'),
#  ('1435', '1435', '3717', 3, 'Confortável serviços.'),
#  ('1436', '1436', '5610', 4, 'Confortável localização.'),
#  ('1437', '1437', '811', 4, 'Incrível infraestrutura.'),
#  ('1438', '1438', '5489', 2, 'Terrível localização.'),
#  ('1439', '1439', '106', 4, 'Maravilhosa localização.'),
#  ('144', '144', '3871', 3, 'Agradável serviços.'),
#  ('1440', '1440', '1988', 2, 'Ruim limpeza.'),
#  ('1441', '1441', '3334', 2, 'Ruim limpeza.'),
#  ('1442', '1442', '8788', 5, 'Maravilhosa infraestrutura.'),
#  ('1443', '1443', '8813', 2, 'Horrível localização.'),
#  ('1444', '1444', '6661', 4, 'Confortável serviços.'),
#  ('1445', '1445', '2958', 1, 'Desagradável atendimento.'),
#  ('1446', '1446', '3093', 1, 'Ruim serviços.'),
#  ('1447', '1447', '2835', 1, 'Terrível atendimento.'),
#  ('1448', '1448', '9956', 5, 'Confortável localização.'),
#  ('1449', '1449', '6566', 2, 'Ruim infraestrutura.'),
#  ('145', '145', '7790', 4, 'Agradável localização.'),
#  ('1450', '1450', '3455', 3, 'Excelente serviços.'),
#  ('1451', '1451', '1055', 5, 'Ótima localização.'),
#  ('1452', '1452', '1929', 1, 'Terrível localização.'),
#  ('1453', '1453', '4956', 1, 'Ruim serviços.'),
#  ('1454', '1454', '4070', 5, 'Ótima infraestrutura.'),
#  ('1455', '1455', '6364', 5, 'Agradável localização.'),
#  ('1456', '1456', '2715', 1, 'Terrível infraestrutura.'),
#  ('1457', '1457', '4340', 4, 'Ótima atendimento.'),
#  ('1458', '1458', '7720', 2, 'Ruim limpeza.'),
#  ('1459', '1459', '1824', 1, 'Desconfortável limpeza.'),
#  ('146', '146', '5763', 1, 'Desagradável localização.'),
#  ('1460', '1460', '7773', 5, 'Confortável limpeza.'),
#  ('1461', '1461', '425', 1, 'Terrível localização.'),
#  ('1462', '1462', '2706', 4, 'Ótima limpeza.'),
#  ('1463', '1463', '3983', 2, 'Desconfortável infraestrutura.'),
#  ('1464', '1464', '2166', 5, 'Maravilhosa limpeza.'),
#  ('1465', '1465', '59', 1, 'Desconfortável atendimento.'),
#  ('1466', '1466', '6736', 3, 'Excelente limpeza.'),
#  ('1467', '1467', '997', 4, 'Incrível limpeza.'),
#  ('1468', '1468', '9637', 1, 'Péssima limpeza.'),
#  ('1469', '1469', '5142', 1, 'Desconfortável serviços.'),
#  ('147', '147', '877', 3, 'Agradável serviços.'),
#  ('1470', '1470', '3409', 3, 'Agradável serviços.'),
#  ('1471', '1471', '2480', 5, 'Maravilhosa limpeza.'),
#  ('1472', '1472', '108', 2, 'Desagradável atendimento.'),
#  ('1473', '1473', '1750', 2, 'Péssima serviços.'),
#  ('1474', '1474', '7141', 1, 'Terrível localização.'),
#  ('1475', '1475', '9956', 3, 'Ótima infraestrutura.'),
#  ('1476', '1476', '1433', 4, 'Incrível infraestrutura.'),
#  ('1477', '1477', '8309', 1, 'Desagradável limpeza.'),
#  ('1478', '1478', '9555', 2, 'Horrível infraestrutura.'),
#  ('1479', '1479', '4051', 2, 'Terrível limpeza.'),
#  ('148', '148', '1485', 2, 'Horrível atendimento.'),
#  ('1480', '1480', '9945', 1, 'Horrível localização.'),
#  ('1481', '1481', '6437', 1, 'Terrível serviços.'),
#  ('1482', '1482', '3378', 1, 'Terrível limpeza.'),
#  ('1483', '1483', '1562', 1, 'Desconfortável atendimento.'),
#  ('1484', '1484', '43', 4, 'Incrível localização.'),
#  ('1485', '1485', '242', 5, 'Ótima atendimento.'),
#  ('1486', '1486', '540', 1, 'Horrível infraestrutura.'),
#  ('1487', '1487', '2101', 3, 'Excelente atendimento.'),
#  ('1488', '1488', '2428', 4, 'Incrível infraestrutura.'),
#  ('1489', '1489', '8872', 3, 'Maravilhosa serviços.'),
#  ('149', '149', '3338', 3, 'Agradável localização.'),
#  ('1490', '1490', '3221', 2, 'Desagradável serviços.'),
#  ('1491', '1491', '7411', 5, 'Confortável serviços.'),
#  ('1492', '1492', '6720', 4, 'Excelente localização.'),
#  ('1493', '1493', '2877', 5, 'Incrível limpeza.'),
#  ('1494', '1494', '5310', 3, 'Maravilhosa limpeza.'),
#  ('1495', '1495', '8206', 1, 'Desconfortável limpeza.'),
#  ('1496', '1496', '685', 4, 'Maravilhosa limpeza.'),
#  ('1497', '1497', '2108', 1, 'Desconfortável limpeza.'),
#  ('1498', '1498', '1501', 2, 'Ruim infraestrutura.'),
#  ('1499', '1499', '3769', 4, 'Ótima infraestrutura.'),
#  ('15', '15', '3739', 2, 'Péssima infraestrutura.'),
#  ('150', '150', '5981', 1, 'Ruim atendimento.'),
#  ('1500', '1500', '3919', 5, 'Agradável atendimento.'),
#  ('1501', '1501', '6425', 4, 'Confortável serviços.'),
#  ('1502', '1502', '4987', 5, 'Excelente atendimento.'),
#  ('1503', '1503', '7688', 5, 'Ótima serviços.'),
#  ('1504', '1504', '4306', 3, 'Incrível infraestrutura.'),
#  ('1505', '1505', '5571', 1, 'Desconfortável infraestrutura.'),
#  ('1506', '1506', '1579', 3, 'Maravilhosa limpeza.'),
#  ('1507', '1507', '7479', 3, 'Confortável serviços.'),
#  ('1508', '1508', '3565', 1, 'Desagradável atendimento.'),
#  ('1509', '1509', '5974', 5, 'Excelente atendimento.'),
#  ('151', '151', '5201', 5, 'Ótima infraestrutura.'),
#  ('1510', '1510', '9287', 5, 'Excelente serviços.'),
#  ('1511', '1511', '6095', 3, 'Agradável localização.'),
#  ('1512', '1512', '3016', 4, 'Ótima atendimento.'),
#  ('1513', '1513', '873', 2, 'Desconfortável atendimento.'),
#  ('1514', '1514', '4640', 4, 'Ótima infraestrutura.'),
#  ('1515', '1515', '5472', 1, 'Terrível localização.'),
#  ('1516', '1516', '9326', 4, 'Excelente atendimento.'),
#  ('1517', '1517', '5541', 5, 'Incrível localização.'),
#  ('1518', '1518', '715', 2, 'Terrível infraestrutura.'),
#  ('1519', '1519', '4279', 1, 'Péssima atendimento.'),
#  ('152', '152', '7393', 5, 'Maravilhosa infraestrutura.'),
#  ('1520', '1520', '6051', 5, 'Incrível localização.'),
#  ('1521', '1521', '9259', 4, 'Agradável localização.'),
#  ('1522', '1522', '2549', 4, 'Agradável atendimento.'),
#  ('1523', '1523', '3802', 3, 'Agradável infraestrutura.'),
#  ('1524', '1524', '5344', 2, 'Ruim infraestrutura.'),
#  ('1525', '1525', '509', 2, 'Péssima infraestrutura.'),
#  ('1526', '1526', '1456', 3, 'Maravilhosa infraestrutura.'),
#  ('1527', '1527', '5036', 5, 'Confortável atendimento.'),
#  ('1528', '1528', '7879', 4, 'Ótima atendimento.'),
#  ('1529', '1529', '4303', 4, 'Agradável localização.'),
#  ('153', '153', '5910', 4, 'Excelente localização.'),
#  ('1530', '1530', '9346', 5, 'Maravilhosa infraestrutura.'),
#  ('1531', '1531', '8765', 5, 'Excelente serviços.'),
#  ('1532', '1532', '9516', 5, 'Ótima infraestrutura.'),
#  ('1533', '1533', '8488', 3, 'Excelente atendimento.'),
#  ('1534', '1534', '7808', 5, 'Maravilhosa atendimento.'),
#  ('1535', '1535', '6959', 4, 'Maravilhosa infraestrutura.'),
#  ('1536', '1536', '9013', 5, 'Excelente limpeza.'),
#  ('1537', '1537', '3590', 3, 'Agradável limpeza.'),
#  ('1538', '1538', '1711', 4, 'Excelente limpeza.'),
#  ('1539', '1539', '2612', 3, 'Excelente localização.'),
#  ('154', '154', '4146', 3, 'Confortável serviços.'),
#  ('1540', '1540', '1247', 4, 'Agradável infraestrutura.'),
#  ('1541', '1541', '364', 5, 'Incrível atendimento.'),
#  ('1542', '1542', '2699', 3, 'Agradável atendimento.'),
#  ('1543', '1543', '149', 2, 'Horrível atendimento.'),
#  ('1544', '1544', '2137', 3, 'Ótima limpeza.'),
#  ('1545', '1545', '6738', 2, 'Desagradável infraestrutura.'),
#  ('1546', '1546', '1982', 3, 'Ótima infraestrutura.'),
#  ('1547', '1547', '585', 4, 'Ótima localização.'),
#  ('1548', '1548', '272', 2, 'Desconfortável atendimento.'),
#  ('1549', '1549', '3457', 3, 'Incrível localização.'),
#  ('155', '155', '4804', 1, 'Desconfortável localização.'),
#  ('1550', '1550', '7460', 5, 'Excelente limpeza.'),
#  ('1551', '1551', '6961', 1, 'Ruim serviços.'),
#  ('1552', '1552', '7153', 4, 'Agradável atendimento.'),
#  ('1553', '1553', '288', 1, 'Ruim localização.'),
#  ('1554', '1554', '2511', 3, 'Maravilhosa localização.'),
#  ('1555', '1555', '5022', 5, 'Agradável limpeza.'),
#  ('1556', '1556', '1308', 3, 'Agradável infraestrutura.'),
#  ('1557', '1557', '5032', 3, 'Confortável serviços.'),
#  ('1558', '1558', '428', 2, 'Terrível limpeza.'),
#  ('1559', '1559', '3825', 2, 'Ruim localização.'),
#  ('156', '156', '6050', 2, 'Péssima atendimento.'),
#  ('1560', '1560', '4254', 1, 'Desagradável atendimento.'),
#  ('1561', '1561', '9547', 1, 'Péssima limpeza.'),
#  ('1562', '1562', '2369', 3, 'Ótima serviços.'),
#  ('1563', '1563', '4884', 3, 'Ótima atendimento.'),
#  ('1564', '1564', '2516', 3, 'Confortável infraestrutura.'),
#  ('1565', '1565', '4933', 3, 'Excelente serviços.'),
#  ('1566', '1566', '5620', 3, 'Incrível serviços.'),
#  ('1567', '1567', '5250', 2, 'Terrível localização.'),
#  ('1568', '1568', '8975', 3, 'Incrível limpeza.'),
#  ('1569', '1569', '7165', 4, 'Incrível atendimento.'),
#  ('157', '157', '9398', 1, 'Terrível infraestrutura.'),
#  ('1570', '1570', '2094', 4, 'Excelente atendimento.'),
#  ('1571', '1571', '9388', 2, 'Desagradável infraestrutura.'),
#  ('1572', '1572', '3838', 2, 'Horrível limpeza.'),
#  ('1573', '1573', '9396', 4, 'Maravilhosa serviços.'),
#  ('1574', '1574', '1178', 1, 'Desagradável infraestrutura.'),
#  ('1575', '1575', '7628', 5, 'Agradável infraestrutura.'),
#  ('1576', '1576', '2399', 2, 'Desconfortável infraestrutura.'),
#  ('1577', '1577', '2060', 2, 'Horrível limpeza.'),
#  ('1578', '1578', '491', 5, 'Excelente infraestrutura.'),
#  ('1579', '1579', '4695', 2, 'Ruim serviços.'),
#  ('158', '158', '5621', 2, 'Horrível atendimento.'),
#  ('1580', '1580', '1462', 5, 'Agradável atendimento.'),
#  ('1581', '1581', '2132', 1, 'Horrível limpeza.'),
#  ('1582', '1582', '1026', 3, 'Agradável serviços.'),
#  ('1583', '1583', '161', 3, 'Confortável serviços.'),
#  ('1584', '1584', '9646', 5, 'Ótima serviços.'),
#  ('1585', '1585', '2685', 3, 'Confortável infraestrutura.'),
#  ('1586', '1586', '1105', 2, 'Terrível infraestrutura.'),
#  ('1587', '1587', '883', 3, 'Maravilhosa atendimento.'),
#  ('1588', '1588', '3495', 3, 'Maravilhosa atendimento.'),
#  ('1589', '1589', '2691', 1, 'Péssima atendimento.'),
#  ('159', '159', '650', 1, 'Péssima infraestrutura.'),
#  ('1590', '1590', '4041', 4, 'Maravilhosa atendimento.'),
#  ('1591', '1591', '3869', 1, 'Péssima serviços.'),
#  ('1592', '1592', '7280', 5, 'Ótima atendimento.'),
#  ('1593', '1593', '1665', 5, 'Agradável atendimento.'),
#  ('1594', '1594', '177', 5, 'Excelente serviços.'),
#  ('1595', '1595', '9555', 5, 'Confortável infraestrutura.'),
#  ('1596', '1596', '1132', 5, 'Incrível localização.'),
#  ('1597', '1597', '4097', 2, 'Péssima serviços.'),
#  ('1598', '1598', '6325', 1, 'Péssima serviços.'),
#  ('1599', '1599', '9168', 5, 'Maravilhosa localização.'),
#  ('16', '16', '5784', 3, 'Maravilhosa atendimento.'),
#  ('160', '160', '866', 4, 'Maravilhosa serviços.'),
#  ('1600', '1600', '166', 2, 'Ruim localização.'),
#  ('1601', '1601', '3635', 4, 'Excelente serviços.'),
#  ('1602', '1602', '9580', 2, 'Desagradável limpeza.'),
#  ('1603', '1603', '6681', 4, 'Ótima infraestrutura.'),
#  ('1604', '1604', '740', 4, 'Incrível infraestrutura.'),
#  ('1605', '1605', '4233', 1, 'Terrível serviços.'),
#  ('1606', '1606', '1735', 4, 'Maravilhosa atendimento.'),
#  ('1607', '1607', '7017', 2, 'Desconfortável serviços.'),
#  ('1608', '1608', '1465', 2, 'Terrível localização.'),
#  ('1609', '1609', '210', 4, 'Maravilhosa infraestrutura.'),
#  ('161', '161', '2655', 4, 'Incrível serviços.'),
#  ('1610', '1610', '4952', 5, 'Excelente localização.'),
#  ('1611', '1611', '5204', 4, 'Excelente infraestrutura.'),
#  ('1612', '1612', '1407', 1, 'Ruim serviços.'),
#  ('1613', '1613', '9434', 5, 'Excelente atendimento.'),
#  ('1614', '1614', '5667', 1, 'Desconfortável limpeza.'),
#  ('1615', '1615', '829', 4, 'Maravilhosa infraestrutura.'),
#  ('1616', '1616', '3667', 3, 'Agradável limpeza.'),
#  ('1617', '1617', '9120', 4, 'Incrível limpeza.'),
#  ('1618', '1618', '9445', 5, 'Ótima infraestrutura.'),
#  ('1619', '1619', '5623', 2, 'Ruim serviços.'),
#  ('162', '162', '5921', 1, 'Desagradável infraestrutura.'),
#  ('1620', '1620', '4659', 3, 'Agradável localização.'),
#  ('1621', '1621', '3783', 4, 'Confortável serviços.'),
#  ('1622', '1622', '5319', 1, 'Desconfortável localização.'),
#  ('1623', '1623', '2460', 5, 'Ótima limpeza.'),
#  ('1624', '1624', '5166', 2, 'Péssima infraestrutura.'),
#  ('1625', '1625', '799', 4, 'Agradável atendimento.'),
#  ('1626', '1626', '8356', 2, 'Horrível atendimento.'),
#  ('1627', '1627', '9586', 1, 'Péssima localização.'),
#  ('1628', '1628', '8952', 1, 'Horrível atendimento.'),
#  ('1629', '1629', '6927', 1, 'Desagradável serviços.'),
#  ('163', '163', '7997', 4, 'Ótima serviços.'),
#  ('1630', '1630', '238', 3, 'Agradável atendimento.'),
#  ('1631', '1631', '2534', 4, 'Excelente limpeza.'),
#  ('1632', '1632', '1784', 4, 'Excelente infraestrutura.'),
#  ('1633', '1633', '2637', 1, 'Horrível serviços.'),
#  ('1634', '1634', '7753', 3, 'Ótima serviços.'),
#  ('1635', '1635', '2348', 5, 'Agradável limpeza.'),
#  ('1636', '1636', '5256', 5, 'Maravilhosa serviços.'),
#  ('1637', '1637', '8028', 4, 'Agradável atendimento.'),
#  ('1638', '1638', '1678', 3, 'Ótima localização.'),
#  ('1639', '1639', '8108', 4, 'Incrível atendimento.'),
#  ('164', '164', '7543', 4, 'Agradável localização.'),
#  ('1640', '1640', '6269', 3, 'Incrível localização.'),
#  ('1641', '1641', '3324', 4, 'Excelente localização.'),
#  ('1642', '1642', '162', 4, 'Excelente limpeza.'),
#  ('1643', '1643', '2630', 1, 'Terrível localização.'),
#  ('1644', '1644', '2982', 5, 'Confortável limpeza.'),
#  ('1645', '1645', '221', 5, 'Agradável atendimento.'),
#  ('1646', '1646', '1609', 5, 'Agradável localização.'),
#  ('1647', '1647', '1716', 1, 'Horrível localização.'),
#  ('1648', '1648', '1365', 1, 'Desconfortável localização.'),
#  ('1649', '1649', '1393', 1, 'Péssima localização.'),
#  ('165', '165', '7033', 3, 'Incrível atendimento.'),
#  ('1650', '1650', '8463', 3, 'Incrível atendimento.'),
#  ('1651', '1651', '2877', 3, 'Agradável infraestrutura.'),
#  ('1652', '1652', '9978', 5, 'Incrível infraestrutura.'),
#  ('1653', '1653', '1867', 4, 'Ótima atendimento.'),
#  ('1654', '1654', '5822', 5, 'Maravilhosa limpeza.'),
#  ('1655', '1655', '423', 1, 'Terrível atendimento.'),
#  ('1656', '1656', '6569', 5, 'Excelente localização.'),
#  ('1657', '1657', '8413', 2, 'Desconfortável atendimento.'),
#  ('1658', '1658', '2636', 5, 'Maravilhosa localização.'),
#  ('1659', '1659', '6528', 2, 'Desconfortável limpeza.'),
#  ('166', '166', '8881', 5, 'Agradável atendimento.'),
#  ('1660', '1660', '2286', 3, 'Agradável localização.'),
#  ('1661', '1661', '4761', 3, 'Excelente atendimento.'),
#  ('1662', '1662', '5383', 3, 'Excelente limpeza.'),
#  ('1663', '1663', '2002', 5, 'Maravilhosa atendimento.'),
#  ('1664', '1664', '1004', 2, 'Horrível atendimento.'),
#  ('1665', '1665', '4943', 5, 'Confortável serviços.'),
#  ('1666', '1666', '300', 4, 'Agradável serviços.'),
#  ('1667', '1667', '7345', 1, 'Horrível localização.'),
#  ('1668', '1668', '2083', 5, 'Ótima atendimento.'),
#  ('1669', '1669', '5794', 4, 'Confortável localização.'),
#  ('167', '167', '129', 3, 'Ótima atendimento.'),
#  ('1670', '1670', '8162', 1, 'Péssima infraestrutura.'),
#  ('1671', '1671', '1301', 2, 'Péssima localização.'),
#  ('1672', '1672', '4085', 4, 'Confortável atendimento.'),
#  ('1673', '1673', '5662', 4, 'Excelente localização.'),
#  ('1674', '1674', '9527', 4, 'Agradável limpeza.'),
#  ('1675', '1675', '9618', 1, 'Desagradável atendimento.'),
#  ('1676', '1676', '4698', 1, 'Desagradável localização.'),
#  ('1677', '1677', '1636', 4, 'Maravilhosa limpeza.'),
#  ('1678', '1678', '6806', 2, 'Ruim localização.'),
#  ('1679', '1679', '212', 3, 'Excelente atendimento.'),
#  ('168', '168', '6445', 5, 'Excelente infraestrutura.'),
#  ('1680', '1680', '9870', 5, 'Maravilhosa serviços.'),
#  ('1681', '1681', '4379', 1, 'Ruim serviços.'),
#  ('1682', '1682', '7988', 3, 'Agradável atendimento.'),
#  ('1683', '1683', '3440', 2, 'Terrível localização.'),
#  ('1684', '1684', '8560', 5, 'Excelente infraestrutura.'),
#  ('1685', '1685', '3771', 3, 'Ótima atendimento.'),
#  ('1686', '1686', '5397', 3, 'Maravilhosa limpeza.'),
#  ('1687', '1687', '2732', 2, 'Horrível atendimento.'),
#  ('1688', '1688', '1764', 3, 'Ótima infraestrutura.'),
#  ('1689', '1689', '4183', 5, 'Maravilhosa infraestrutura.'),
#  ('169', '169', '5519', 5, 'Agradável infraestrutura.'),
#  ('1690', '1690', '5617', 4, 'Excelente infraestrutura.'),
#  ('1691', '1691', '8688', 5, 'Excelente limpeza.'),
#  ('1692', '1692', '4859', 1, 'Desconfortável localização.'),
#  ('1693', '1693', '9008', 1, 'Desagradável atendimento.'),
#  ('1694', '1694', '120', 4, 'Incrível atendimento.'),
#  ('1695', '1695', '721', 2, 'Desconfortável localização.'),
#  ('1696', '1696', '4083', 2, 'Ruim limpeza.'),
#  ('1697', '1697', '262', 5, 'Confortável localização.'),
#  ('1698', '1698', '2492', 5, 'Confortável infraestrutura.'),
#  ('1699', '1699', '2426', 2, 'Terrível limpeza.'),
#  ('17', '17', '4744', 1, 'Terrível serviços.'),
#  ('170', '170', '9764', 2, 'Péssima serviços.'),
#  ('1700', '1700', '5614', 2, 'Ruim infraestrutura.'),
#  ('1701', '1701', '1341', 4, 'Agradável localização.'),
#  ('1702', '1702', '8887', 3, 'Ótima serviços.'),
#  ('1703', '1703', '5160', 5, 'Incrível limpeza.'),
#  ('1704', '1704', '6115', 5, 'Excelente limpeza.'),
#  ('1705', '1705', '5696', 4, 'Agradável serviços.'),
#  ('1706', '1706', '1312', 3, 'Incrível serviços.'),
#  ('1707', '1707', '8701', 4, 'Confortável atendimento.'),
#  ('1708', '1708', '3706', 4, 'Confortável atendimento.'),
#  ('1709', '1709', '5948', 1, 'Horrível serviços.'),
#  ('171', '171', '6310', 5, 'Excelente limpeza.'),
#  ('1710', '1710', '2796', 4, 'Maravilhosa serviços.'),
#  ('1711', '1711', '7856', 4, 'Ótima serviços.'),
#  ('1712', '1712', '3871', 4, 'Agradável atendimento.'),
#  ('1713', '1713', '5414', 3, 'Ótima atendimento.'),
#  ('1714', '1714', '4419', 5, 'Agradável limpeza.'),
#  ('1715', '1715', '6803', 5, 'Agradável serviços.'),
#  ('1716', '1716', '5477', 5, 'Confortável limpeza.'),
#  ('1717', '1717', '3831', 2, 'Péssima localização.'),
#  ('1718', '1718', '8498', 4, 'Ótima atendimento.'),
#  ('1719', '1719', '3849', 5, 'Incrível serviços.'),
#  ('172', '172', '59', 3, 'Excelente serviços.'),
#  ('1720', '1720', '3479', 1, 'Péssima atendimento.'),
#  ('1721', '1721', '5917', 3, 'Confortável infraestrutura.'),
#  ('1722', '1722', '6178', 3, 'Agradável serviços.'),
#  ('1723', '1723', '1054', 3, 'Agradável limpeza.'),
#  ('1724', '1724', '9475', 5, 'Agradável atendimento.'),
#  ('1725', '1725', '5313', 4, 'Excelente atendimento.'),
#  ('1726', '1726', '2954', 1, 'Terrível serviços.'),
#  ('1727', '1727', '4789', 1, 'Desagradável atendimento.'),
#  ('1728', '1728', '5713', 4, 'Confortável limpeza.'),
#  ('1729', '1729', '7015', 3, 'Excelente limpeza.'),
#  ('173', '173', '5030', 5, 'Confortável serviços.'),
#  ('1730', '1730', '4317', 1, 'Desconfortável localização.'),
#  ('1731', '1731', '1550', 4, 'Confortável serviços.'),
#  ('1732', '1732', '3703', 3, 'Incrível atendimento.'),
#  ('1733', '1733', '4948', 4, 'Maravilhosa serviços.'),
#  ('1734', '1734', '4538', 3, 'Ótima infraestrutura.'),
#  ('1735', '1735', '3866', 1, 'Ruim localização.'),
#  ('1736', '1736', '7460', 3, 'Maravilhosa serviços.'),
#  ('1737', '1737', '374', 3, 'Maravilhosa limpeza.'),
#  ('1738', '1738', '6046', 1, 'Ruim localização.'),
#  ('1739', '1739', '5465', 1, 'Ruim serviços.'),
#  ('174', '174', '2750', 3, 'Ótima infraestrutura.'),
#  ('1740', '1740', '310', 2, 'Péssima limpeza.'),
#  ('1741', '1741', '6143', 1, 'Desagradável serviços.'),
#  ('1742', '1742', '8766', 1, 'Desagradável infraestrutura.'),
#  ('1743', '1743', '5126', 5, 'Agradável limpeza.'),
#  ('1744', '1744', '1645', 5, 'Incrível localização.'),
#  ('1745', '1745', '3092', 2, 'Desconfortável limpeza.'),
#  ('1746', '1746', '6213', 3, 'Incrível infraestrutura.'),
#  ('1747', '1747', '2444', 5, 'Maravilhosa localização.'),
#  ('1748', '1748', '8767', 5, 'Maravilhosa serviços.'),
#  ('1749', '1749', '7907', 3, 'Maravilhosa localização.'),
#  ('175', '175', '7592', 3, 'Incrível localização.'),
#  ('1750', '1750', '3160', 5, 'Maravilhosa atendimento.'),
#  ('1751', '1751', '703', 2, 'Desagradável localização.'),
#  ('1752', '1752', '7131', 5, 'Incrível infraestrutura.'),
#  ('1753', '1753', '1958', 5, 'Ótima infraestrutura.'),
#  ('1754', '1754', '7023', 4, 'Ótima limpeza.'),
#  ('1755', '1755', '3861', 1, 'Horrível localização.'),
#  ('1756', '1756', '5739', 1, 'Ruim localização.'),
#  ('1757', '1757', '1917', 5, 'Agradável atendimento.'),
#  ('1758', '1758', '3474', 2, 'Péssima localização.'),
#  ('1759', '1759', '667', 1, 'Terrível atendimento.'),
#  ('176', '176', '9564', 4, 'Excelente atendimento.'),
#  ('1760', '1760', '7233', 2, 'Ruim limpeza.'),
#  ('1761', '1761', '5969', 3, 'Maravilhosa limpeza.'),
#  ('1762', '1762', '7541', 3, 'Maravilhosa limpeza.'),
#  ('1763', '1763', '8081', 2, 'Ruim atendimento.'),
#  ('1764', '1764', '1469', 5, 'Confortável infraestrutura.'),
#  ('1765', '1765', '4429', 5, 'Excelente limpeza.'),
#  ('1766', '1766', '5269', 5, 'Agradável infraestrutura.'),
#  ('1767', '1767', '5420', 5, 'Ótima limpeza.'),
#  ('1768', '1768', '2426', 3, 'Agradável infraestrutura.'),
#  ('1769', '1769', '7269', 2, 'Horrível limpeza.'),
#  ('177', '177', '1687', 2, 'Ruim atendimento.'),
#  ('1770', '1770', '4424', 4, 'Incrível atendimento.'),
#  ('1771', '1771', '5155', 3, 'Excelente atendimento.'),
#  ('1772', '1772', '3101', 3, 'Confortável localização.'),
#  ('1773', '1773', '6640', 5, 'Maravilhosa localização.'),
#  ('1774', '1774', '8218', 3, 'Maravilhosa infraestrutura.'),
#  ('1775', '1775', '4804', 5, 'Ótima serviços.'),
#  ('1776', '1776', '6997', 4, 'Excelente serviços.'),
#  ('1777', '1777', '5274', 1, 'Terrível localização.'),
#  ('1778', '1778', '2020', 4, 'Excelente serviços.'),
#  ('1779', '1779', '9309', 4, 'Excelente limpeza.'),
#  ('178', '178', '535', 5, 'Ótima serviços.'),
#  ('1780', '1780', '135', 4, 'Ótima atendimento.'),
#  ('1781', '1781', '2194', 4, 'Excelente atendimento.'),
#  ('1782', '1782', '213', 1, 'Desagradável limpeza.'),
#  ('1783', '1783', '1668', 1, 'Péssima localização.'),
#  ('1784', '1784', '4866', 4, 'Agradável serviços.'),
#  ('1785', '1785', '6577', 1, 'Desagradável limpeza.'),
#  ('1786', '1786', '1297', 2, 'Horrível atendimento.'),
#  ('1787', '1787', '8380', 1, 'Horrível infraestrutura.'),
#  ('1788', '1788', '827', 5, 'Maravilhosa localização.'),
#  ('1789', '1789', '5721', 3, 'Incrível serviços.'),
#  ('179', '179', '8066', 5, 'Confortável limpeza.'),
#  ('1790', '1790', '7350', 2, 'Péssima limpeza.'),
#  ('1791', '1791', '4233', 4, 'Maravilhosa limpeza.'),
#  ('1792', '1792', '8821', 1, 'Péssima infraestrutura.'),
#  ('1793', '1793', '8128', 1, 'Terrível infraestrutura.'),
#  ('1794', '1794', '7109', 3, 'Ótima localização.'),
#  ('1795', '1795', '1138', 1, 'Terrível infraestrutura.'),
#  ('1796', '1796', '5726', 4, 'Excelente localização.'),
#  ('1797', '1797', '3788', 1, 'Ruim serviços.'),
#  ('1798', '1798', '7515', 2, 'Péssima atendimento.'),
#  ('1799', '1799', '645', 2, 'Horrível localização.'),
#  ('18', '18', '5631', 5, 'Agradável atendimento.'),
#  ('1800', '1800', '2980', 2, 'Ruim infraestrutura.'),
#  ('1801', '1801', '2988', 4, 'Confortável limpeza.'),
#  ('1802', '1802', '4405', 5, 'Maravilhosa limpeza.'),
#  ('1803', '1803', '1945', 4, 'Confortável localização.'),
#  ('1804', '1804', '1246', 1, 'Péssima localização.'),
#  ('1805', '1805', '3619', 2, 'Terrível limpeza.'),
#  ('1806', '1806', '4532', 2, 'Ruim limpeza.'),
#  ('1807', '1807', '316', 5, 'Incrível localização.'),
#  ('1808', '1808', '5461', 1, 'Desconfortável infraestrutura.'),
#  ('1809', '1809', '7545', 3, 'Excelente atendimento.'),
#  ('181', '181', '1235', 2, 'Desconfortável atendimento.'),
#  ('1810', '1810', '8093', 5, 'Agradável serviços.'),
#  ('1811', '1811', '7054', 1, 'Desagradável atendimento.'),
#  ('1812', '1812', '6913', 1, 'Desconfortável atendimento.'),
#  ('1813', '1813', '3000', 5, 'Confortável serviços.'),
#  ('1814', '1814', '6745', 2, 'Horrível localização.'),
#  ('1815', '1815', '1367', 1, 'Desagradável localização.'),
#  ('1816', '1816', '2907', 1, 'Terrível localização.'),
#  ('1817', '1817', '8480', 3, 'Ótima limpeza.'),
#  ('1818', '1818', '3843', 2, 'Terrível limpeza.'),
#  ('1819', '1819', '6719', 2, 'Péssima localização.'),
#  ('182', '182', '2915', 4, 'Ótima infraestrutura.'),
#  ('1820', '1820', '66', 2, 'Terrível infraestrutura.'),
#  ('1821', '1821', '5467', 3, 'Agradável infraestrutura.'),
#  ('1822', '1822', '9534', 1, 'Péssima limpeza.'),
#  ('1823', '1823', '6087', 5, 'Ótima serviços.'),
#  ('1824', '1824', '4149', 5, 'Agradável limpeza.'),
#  ('1825', '1825', '9370', 2, 'Desagradável localização.'),
#  ('1826', '1826', '4627', 3, 'Incrível infraestrutura.'),
#  ('1827', '1827', '134', 4, 'Maravilhosa limpeza.'),
#  ('1828', '1828', '1557', 4, 'Confortável atendimento.'),
#  ('1829', '1829', '5430', 4, 'Ótima atendimento.'),
#  ('183', '183', '7833', 4, 'Ótima atendimento.'),
#  ('1830', '1830', '9490', 5, 'Incrível localização.'),
#  ('1831', '1831', '3468', 2, 'Terrível serviços.'),
#  ('1832', '1832', '7704', 2, 'Desconfortável serviços.'),
#  ('1833', '1833', '2848', 5, 'Ótima atendimento.'),
#  ('1834', '1834', '2405', 2, 'Desconfortável serviços.'),
#  ('1835', '1835', '769', 2, 'Desconfortável serviços.'),
#  ('1836', '1836', '1015', 1, 'Desagradável limpeza.'),
#  ('1837', '1837', '8033', 1, 'Ruim infraestrutura.'),
#  ('1838', '1838', '9503', 3, 'Excelente localização.'),
#  ('1839', '1839', '6231', 4, 'Excelente localização.'),
#  ('184', '184', '2448', 3, 'Confortável localização.'),
#  ('1840', '1840', '5903', 2, 'Péssima infraestrutura.'),
#  ('1841', '1841', '3974', 1, 'Horrível infraestrutura.'),
#  ('1842', '1842', '482', 1, 'Terrível limpeza.'),
#  ('1843', '1843', '9669', 4, 'Excelente limpeza.'),
#  ('1844', '1844', '2973', 1, 'Desconfortável serviços.'),
#  ('1845', '1845', '4634', 1, 'Desconfortável localização.'),
#  ('1846', '1846', '856', 2, 'Péssima serviços.'),
#  ('1847', '1847', '9111', 2, 'Horrível localização.'),
#  ('1848', '1848', '5036', 5, 'Incrível serviços.'),
#  ('1849', '1849', '2436', 2, 'Ruim serviços.'),
#  ('185', '185', '7356', 2, 'Desconfortável limpeza.'),
#  ('1850', '1850', '908', 2, 'Ruim atendimento.'),
#  ('1851', '1851', '5051', 1, 'Horrível infraestrutura.'),
#  ('1852', '1852', '9919', 4, 'Ótima limpeza.'),
#  ('1853', '1853', '2826', 2, 'Péssima serviços.'),
#  ('1854', '1854', '5117', 1, 'Terrível infraestrutura.'),
#  ('1855', '1855', '6881', 2, 'Horrível serviços.'),
#  ('1856', '1856', '3568', 1, 'Péssima atendimento.'),
#  ('1857', '1857', '9183', 3, 'Confortável infraestrutura.'),
#  ('1858', '1858', '3895', 2, 'Terrível limpeza.'),
#  ('1859', '1859', '4895', 3, 'Ótima localização.'),
#  ('186', '186', '5801', 5, 'Maravilhosa limpeza.'),
#  ('1860', '1860', '4895', 5, 'Ótima atendimento.'),
#  ('1861', '1861', '3643', 2, 'Terrível limpeza.'),
#  ('1862', '1862', '6475', 3, 'Confortável serviços.'),
#  ('1863', '1863', '3699', 1, 'Desagradável infraestrutura.'),
#  ('1864', '1864', '3179', 4, 'Excelente localização.'),
#  ('1865', '1865', '153', 5, 'Confortável localização.'),
#  ('1866', '1866', '4287', 4, 'Ótima localização.'),
#  ('1867', '1867', '3573', 4, 'Excelente serviços.'),
#  ('1868', '1868', '982', 2, 'Terrível atendimento.'),
#  ('1869', '1869', '9356', 5, 'Ótima localização.'),
#  ('187', '187', '620', 5, 'Maravilhosa localização.'),
#  ('1870', '1870', '8563', 2, 'Terrível limpeza.'),
#  ('1871', '1871', '2103', 2, 'Horrível infraestrutura.'),
#  ('1872', '1872', '178', 1, 'Desconfortável limpeza.'),
#  ('1873', '1873', '9467', 4, 'Ótima infraestrutura.'),
#  ('1874', '1874', '5102', 5, 'Incrível localização.'),
#  ('1875', '1875', '1809', 1, 'Desagradável serviços.'),
#  ('1876', '1876', '1710', 3, 'Confortável infraestrutura.'),
#  ('1877', '1877', '6410', 1, 'Desagradável atendimento.'),
#  ('1878', '1878', '8585', 4, 'Ótima serviços.'),
#  ('1879', '1879', '8102', 3, 'Ótima localização.'),
#  ('188', '188', '4991', 5, 'Maravilhosa atendimento.'),
#  ('1880', '1880', '8407', 5, 'Agradável infraestrutura.'),
#  ('1881', '1881', '6058', 3, 'Excelente infraestrutura.'),
#  ('1882', '1882', '4493', 3, 'Maravilhosa localização.'),
#  ('1883', '1883', '2521', 2, 'Horrível infraestrutura.'),
#  ('1884', '1884', '214', 5, 'Excelente serviços.'),
#  ('1885', '1885', '7724', 3, 'Ótima atendimento.'),
#  ('1886', '1886', '4327', 4, 'Maravilhosa serviços.'),
#  ('1887', '1887', '4024', 2, 'Terrível serviços.'),
#  ('1888', '1888', '6637', 1, 'Terrível localização.'),
#  ('1889', '1889', '4410', 5, 'Maravilhosa serviços.'),
#  ('189', '189', '174', 2, 'Horrível limpeza.'),
#  ('1890', '1890', '2982', 5, 'Maravilhosa infraestrutura.'),
#  ('1891', '1891', '3435', 5, 'Ótima limpeza.'),
#  ('1892', '1892', '4607', 4, 'Ótima limpeza.'),
#  ('1893', '1893', '6812', 4, 'Maravilhosa infraestrutura.'),
#  ('1894', '1894', '4829', 3, 'Confortável localização.'),
#  ('1895', '1895', '9083', 1, 'Horrível infraestrutura.'),
#  ('1896', '1896', '561', 2, 'Péssima localização.'),
#  ('1897', '1897', '3035', 2, 'Desagradável infraestrutura.'),
#  ('1898', '1898', '189', 1, 'Péssima infraestrutura.'),
#  ('1899', '1899', '8581', 2, 'Horrível atendimento.'),
#  ...]

# %%
query = f"""
DROP PROCEDURE IF EXISTS hello_world;

CREATE PROCEDURE hello_world()
BEGIN
    DECLARE texto char(20) DEFAULT 'HELLO WORLD';
    SELECT texto;
END
"""

result = execute_query(query)
# Out:
# Executing query:
# DROP PROCEDURE IF EXISTS hello_world;
#
# CREATE PROCEDURE hello_world()
# BEGIN
#     DECLARE texto char(20) DEFAULT 'HELLO WORLD';
#     SELECT texto;
# END
#  with params: None

# %%
query = f"""
CALL hello_world()
"""

result = execute_query(query)
result
# Out:
# Executing query:
# CALL hello_world()
#  with params: None
#
#
# Query returned 1 rows.
# [('HELLO WORLD',)]

# %%
query = f"""
DROP PROCEDURE IF EXISTS tipos_dados;

CREATE PROCEDURE tipos_dados()
BEGIN
    DECLARE v_aluguel VARCHAR(20) DEFAULT 10001;
    DECLARE v_cliente VARCHAR(20) DEFAULT 1002;
    DECLARE v_hospedagem VARCHAR(20) DEFAULT 8635;
    DECLARE v_data_inicio DATE DEFAULT '2023-03-01';
    DECLARE v_data_fim DATE DEFAULT '2023-03-05';
    DECLARE v_preco DECIMAL(10,2) DEFAULT 550.23;

    SELECT v_aluguel, v_cliente, v_hospedagem, v_data_inicio, v_data_fim, v_preco;
END
"""

result = execute_query(query)
# Out:
# Executing query:
# DROP PROCEDURE IF EXISTS tipos_dados;
#
# CREATE PROCEDURE tipos_dados()
# BEGIN
#     DECLARE v_aluguel VARCHAR(20) DEFAULT 10001;
#     DECLARE v_cliente VARCHAR(20) DEFAULT 1002;
#     DECLARE v_hospedagem VARCHAR(20) DEFAULT 8635;
#     DECLARE v_data_inicio DATE DEFAULT '2023-03-01';
#     DECLARE v_data_fim DATE DEFAULT '2023-03-05';
#     DECLARE v_preco DECIMAL(10,2) DEFAULT 550.23;
#
#     SELECT v_aluguel, v_cliente, v_hospedagem, v_data_inicio, v_data_fim, v_preco;
# END
#  with params: None

# %%
query = f"""
CALL tipos_dados()
"""

result = execute_query(query)
result
# Out:
# Executing query:
# CALL tipos_dados()
#  with params: None
#
#
# Query returned 1 rows.
# [('10001',
#   '1002',
#   '8635',
#   datetime.date(2023, 3, 1),
#   datetime.date(2023, 3, 5),
#   Decimal('550.23'))]

# %%
query = f"""
DROP PROCEDURE IF EXISTS get_now;

CREATE PROCEDURE get_now()
BEGIN
    DECLARE ts DATETIME DEFAULT localtimestamp();
    SELECT ts;
END
"""

result = execute_query(query)
# Out:
# Executing query:
# DROP PROCEDURE IF EXISTS get_now;
#
# CREATE PROCEDURE get_now()
# BEGIN
#     DECLARE ts DATETIME DEFAULT localtimestamp();
#     SELECT ts;
# END
#  with params: None

# %%
query = f"""
CALL get_now()
"""

result = execute_query(query)
result
# Out:
# Executing query:
# CALL get_now()
#  with params: None
#
#
# Query returned 1 rows.
# [(datetime.datetime(2025, 2, 1, 12, 2, 47),)]

# %% [markdown]
# ADICIONAR ALUGUEL

# %%
query = f"""
DROP PROCEDURE IF EXISTS novo_aluguel;

CREATE PROCEDURE novo_aluguel()
BEGIN
    DECLARE vAluguel VARCHAR(10) DEFAULT 10002;
    DECLARE vCliente VARCHAR(10) DEFAULT 1002;
    DECLARE vHospedagem VARCHAR(10) DEFAULT 8635;
    DECLARE vDataInicio DATE DEFAULT '2023-03-01';
    DECLARE vDataFinal DATE DEFAULT '2023-03-05';
    DECLARE vPrecoTotal DECIMAL(10,2) DEFAULT 550.23;
    INSERT INTO reservas VALUES (vAluguel, vCliente, vHospedagem, vDataInicio,
    vDataFinal, vPrecoTotal);
END
"""

result = execute_query(query)
# Out:
# Executing query:
# DROP PROCEDURE IF EXISTS novo_aluguel;
#
# CREATE PROCEDURE novo_aluguel()
# BEGIN
#     DECLARE vAluguel VARCHAR(10) DEFAULT 10002;
#     DECLARE vCliente VARCHAR(10) DEFAULT 1002;
#     DECLARE vHospedagem VARCHAR(10) DEFAULT 8635;
#     DECLARE vDataInicio DATE DEFAULT '2023-03-01';
#     DECLARE vDataFinal DATE DEFAULT '2023-03-05';
#     DECLARE vPrecoTotal DECIMAL(10,2) DEFAULT 550.23;
#     INSERT INTO reservas VALUES (vAluguel, vCliente, vHospedagem, vDataInicio,
#     vDataFinal, vPrecoTotal);
# END
#  with params: None

# %%
query = f"""
CALL novo_aluguel()
"""

result = execute_query(query)
result
# Out:
# Executing query:
# CALL novo_aluguel()
#  with params: None
#
#
# Error executing query: 1062 (23000): Duplicate entry '10002' for key 'reservas.PRIMARY'
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python39\lib\site-packages\mysql\connector\connection_cext.py:706, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     705         query = query.encode("utf-8")
# --> 706     self._cmysql.query(
#     707         query,
#     708         raw=raw,
#     709         buffered=buffered,
#     710         raw_as_string=raw_as_string,
#     711         query_attrs=self.query_attrs,
#     712     )
#     713 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Duplicate entry '10002' for key 'reservas.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# Cell In[32], line 5
#       1 query = f"""
#       2 CALL novo_aluguel()
#       3 """
# ----> 5 result = execute_query(query)
#       6 result
#
# Cell In[20], line 15, in execute_query(query, params)
#      13     cursor.execute(query, params)
#      14 else:
# ---> 15     cursor.execute(query)
#      17 # For SELECT queries, fetch the results
#      18 if cursor.description:  # This indicates a SELECT query
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python39\lib\site-packages\mysql\connector\cursor_cext.py:357, in CMySQLCursor.execute(self, operation, params, multi)
#     352             raise ProgrammingError(
#     353                 "Not all parameters were used in the SQL statement"
#     354             )
#     356 try:
# --> 357     result = self._connection.cmd_query(
#     358         stmt,
#     359         raw=self._raw,
#     360         buffered=self._buffered,
#     361         raw_as_string=self._raw_as_string,
#     362     )
#     363 except MySQLInterfaceError as err:
#     364     raise get_mysql_exception(
#     365         msg=err.msg, errno=err.errno, sqlstate=err.sqlstate
#     366     ) from err
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python39\lib\site-packages\mysql\connector\opentelemetry\context_propagation.py:97, in with_context_propagation.<locals>.wrapper(cnx, *args, **kwargs)
#      95 # pylint: disable=possibly-used-before-assignment
#      96 if not OTEL_ENABLED or not cnx.otel_context_propagation:
# ---> 97     return method(cnx, *args, **kwargs)
#      99 current_span = trace.get_current_span()
#     100 tp_header = None
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python39\lib\site-packages\mysql\connector\connection_cext.py:714, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     706     self._cmysql.query(
#     707         query,
#     708         raw=raw,
#    (...)
#     711         query_attrs=self.query_attrs,
#     712     )
#     713 except MySQLInterfaceError as err:
# --> 714     raise get_mysql_exception(
#     715         err.errno, msg=err.msg, sqlstate=err.sqlstate
#     716     ) from err
#     717 except AttributeError as err:
#     718     addr = (
#     719         self._unix_socket if self._unix_socket else f"{self._host}:{self._port}"
#     720     )
#
# IntegrityError: 1062 (23000): Duplicate entry '10002' for key 'reservas.PRIMARY'

# %% [markdown]
# PARAMETROS

# %%
query = f"""
DROP PROCEDURE IF EXISTS novo_aluguel;

CREATE PROCEDURE novo_aluguel(
    vAluguel VARCHAR(10),
    vCliente VARCHAR(10),
    vHospedagem VARCHAR(10),
    vDataInicio DATE,
    vDataFinal DATE,
    vPrecoTotal DECIMAL(10,2)
)
BEGIN
    INSERT INTO reservas VALUES (
        vAluguel,
        vCliente,
        vHospedagem, 
        vDataInicio,
        vDataFinal,
        vPrecoTotal
    );
END
"""

result = execute_query(query)

# %%
query = f"""
CALL novo_aluguel(
    '10005',
    '1112',
    '8635',
    '2023-03-06',
    '2023-03-10',
    660.45
)
"""

result = execute_query(query)
result
# Out:
# Executing query:
# CALL novo_aluguel(
#     '10005',
#     '1112',
#     '8635',
#     '2023-03-06',
#     '2023-03-10',
#     660.45
# )
#  with params: None
#
#
# Query returned 1 rows.
# [('Aluguel incluído na base com sucesso.',)]

# %%
query = f"""
SELECT * FROM reservas WHERE reserva_id = 10004
"""

result = execute_query(query)
result
# Out:
# Executing query:
# SELECT * FROM reservas WHERE reserva_id = 10004
#  with params: None
# Query returned 0 rows.
# []

# %%
query = f"""
INSERT INTO reservas VALUES(
    '10007',
    '1112',
    '8635',
    '2023-03-06',
    '2023-03-10',
    660.45
)
"""

result = execute_query(query)
result
# Out:
# Executing query:
# INSERT INTO reservas VALUES(
#     '10007',
#     '1112',
#     '8635',
#     '2023-03-06',
#     '2023-03-10',
#     660.45
# )
#  with params: None
#
#
# 1 rows affected.
# 1

# %%
query = f"""
SELECT * FROM reservas WHERE reserva_id = 10009
"""

result = execute_query(query)
result
# Out:
# Executing query:
# SELECT * FROM reservas WHERE reserva_id = 10009
#  with params: None
#
#
# Query returned 1 rows.
# [('10009',
#   '1112',
#   '8635',
#   datetime.date(2023, 3, 6),
#   datetime.date(2023, 3, 10),
#   Decimal('660.45'))]

# %% [markdown]
# OPERACOES

# %%
query = f"""
SET @txt = 'TESTE';
SELECT @txt;
"""

result = execute_query(query)
result
# Out:
# Executing query:
# SET @txt = 'TESTE';
# SELECT @txt;
#  with params: None

# %%
query = f"""
SELECT DATEDIFF(data_fim, data_inicio) FROM reservas WHERE reserva_id = 10007
"""

result = execute_query(query)
result
# Out:
# Executing query:
# SELECT DATEDIFF(data_fim, data_inicio) FROM reservas WHERE reserva_id = 10007
#  with params: None
#
#
# Query returned 1 rows.
# [(4,)]

# %%
result[0][0]
# Out:
# 4

# %%
query = f"""
DROP PROCEDURE IF EXISTS novo_aluguel;

DELIMITER $$

CREATE PROCEDURE `novo_aluguel`(
    IN vAluguel VARCHAR(10),
    IN vCliente VARCHAR(10),
    IN vHospedagem VARCHAR(10),
    IN vDataInicio DATE,
    IN vDataFinal DATE,
    IN vPrecoTotal DECIMAL(10,2)
)
BEGIN
    INSERT INTO reservas 
    VALUES (
        vAluguel,
        vCliente,
        vHospedagem, 
        vDataInicio,
        vDataFinal,
        vPrecoTotal
    );
END $$

DELIMITER ;
"""

result = execute_query(query)
# Out:
# Executing query:
# DROP PROCEDURE IF EXISTS novo_aluguel;
#
# DELIMITER $$
#
# CREATE PROCEDURE `novo_aluguel`(
#     IN vAluguel VARCHAR(10),
#     IN vCliente VARCHAR(10),
#     IN vHospedagem VARCHAR(10),
#     IN vDataInicio DATE,
#     IN vDataFinal DATE,
#     IN vPrecoTotal DECIMAL(10,2)
# )
# BEGIN
#     INSERT INTO reservas
#     VALUES (
#         vAluguel,
#         vCliente,
#         vHospedagem,
#         vDataInicio,
#         vDataFinal,
#         vPrecoTotal
#     );
# END $$
#
# DELIMITER ;
#  with params: None

# %%
query = f"""
CALL novo_aluguel(
    '10009',
    '1112',
    '8635',
    '2023-03-06',
    '2023-03-10',
    660.45
);
"""

result = execute_query(query)
# Out:
# Executing query:
# CALL novo_aluguel(
#     '10009',
#     '1112',
#     '8635',
#     '2023-03-06',
#     '2023-03-10',
#     660.45
# );
#  with params: None
#
#
# Error executing query: 1305 (42000): PROCEDURE alura.novo_aluguel does not exist
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python39\lib\site-packages\mysql\connector\connection_cext.py:706, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     705         query = query.encode("utf-8")
# --> 706     self._cmysql.query(
#     707         query,
#     708         raw=raw,
#     709         buffered=buffered,
#     710         raw_as_string=raw_as_string,
#     711         query_attrs=self.query_attrs,
#     712     )
#     713 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: PROCEDURE alura.novo_aluguel does not exist
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[55], line 12
#       1 query = f"""
#       2 CALL novo_aluguel(
#       3     '10009',
#    (...)
#       9 );
#      10 """
# ---> 12 result = execute_query(query)
#
# Cell In[20], line 15, in execute_query(query, params)
#      13     cursor.execute(query, params)
#      14 else:
# ---> 15     cursor.execute(query)
#      17 # For SELECT queries, fetch the results
#      18 if cursor.description:  # This indicates a SELECT query
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python39\lib\site-packages\mysql\connector\cursor_cext.py:357, in CMySQLCursor.execute(self, operation, params, multi)
#     352             raise ProgrammingError(
#     353                 "Not all parameters were used in the SQL statement"
#     354             )
#     356 try:
# --> 357     result = self._connection.cmd_query(
#     358         stmt,
#     359         raw=self._raw,
#     360         buffered=self._buffered,
#     361         raw_as_string=self._raw_as_string,
#     362     )
#     363 except MySQLInterfaceError as err:
#     364     raise get_mysql_exception(
#     365         msg=err.msg, errno=err.errno, sqlstate=err.sqlstate
#     366     ) from err
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python39\lib\site-packages\mysql\connector\opentelemetry\context_propagation.py:97, in with_context_propagation.<locals>.wrapper(cnx, *args, **kwargs)
#      95 # pylint: disable=possibly-used-before-assignment
#      96 if not OTEL_ENABLED or not cnx.otel_context_propagation:
# ---> 97     return method(cnx, *args, **kwargs)
#      99 current_span = trace.get_current_span()
#     100 tp_header = None
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python39\lib\site-packages\mysql\connector\connection_cext.py:714, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     706     self._cmysql.query(
#     707         query,
#     708         raw=raw,
#    (...)
#     711         query_attrs=self.query_attrs,
#     712     )
#     713 except MySQLInterfaceError as err:
# --> 714     raise get_mysql_exception(
#     715         err.errno, msg=err.msg, sqlstate=err.sqlstate
#     716     ) from err
#     717 except AttributeError as err:
#     718     addr = (
#     719         self._unix_socket if self._unix_socket else f"{self._host}:{self._port}"
#     720     )
#
# ProgrammingError: 1305 (42000): PROCEDURE alura.novo_aluguel does not exist

# %% [markdown]
# NUMERO DE DIAS

# %%
query = f"""
SELECT '2024-01-01' + INTERVAL 5 YEAR + INTERVAL 3 MONTH + INTERVAL 1 DAY;
"""

result = execute_query(query)
result
# Out:
# Executing query:
# SELECT '2024-01-01' + INTERVAL 5 YEAR + INTERVAL 3 MONTH + INTERVAL 1 DAY;
#  with params: None
#
#
# Query returned 1 rows.
# [('2029-04-02',)]

# %%
'''
DOMINGO - 1
SABADO - 7
'''

query = f"""
SELECT 
DAYOFWEEK('2024-01-7'),
DAYOFWEEK('2024-01-8');
"""
result = execute_query(query)
result
# Out:
# Executing query:
# SELECT
# DAYOFWEEK('2024-01-7'),
# DAYOFWEEK('2024-01-8');
#  with params: None
#
#
# Query returned 1 rows.
# [(1, 2)]
